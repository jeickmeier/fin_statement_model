# %%
#from fin_statement_model.importers.excel_importer import ExcelImporter
import pandas as pd

import os
import sys
import json
import openai

# %%
def build_prompt(spreadsheet_data):
    # Convert any non-serializable objects (like datetime) to strings using default=str.
    json_str = json.dumps(spreadsheet_data, indent=2, default=str)
    
    prompt = (
        "I have a spreadsheet represented as JSON. Each object in the array represents a cell "
        "with its location, formula, precedents, dependencies, and value. For example, the JSON looks like this:\n\n"
        f"{json_str}\n\n"
        "Based on the contents, please provide your best guess of what the row names and "
        "column header names might be. Please return your answer as two additional keys to the input JSON: "
        "'row_name' and 'column_name'. "
        "Only output valid JSON."
    )
    return prompt

# %%
import openpyxl
import re
from openpyxl.utils.cell import coordinate_from_string

def extract_dependencies(formula):
    """
    Extract cell references (dependencies) from a formula string.
    This is a very basic regex, and may need enhancement for complex formulas.
    """
    return re.findall(r"([A-Z]+[0-9]+)", formula)

def load_excel_with_metadata(file_path):
    # Load the workbook twice:
    # one that retains the formulas (data_only=False) and one that contains calculated values (data_only=True)
    wb_formula = openpyxl.load_workbook(file_path, data_only=False)
    wb_value = openpyxl.load_workbook(file_path, data_only=True)
    
    # We're using the active sheet in this example
    sheet_formula = wb_formula.active
    sheet_value = wb_value.active

    cells_data = []

    for row in sheet_formula.iter_rows():
        for cell in row:
            # Extract column letter and row number using coordinate_from_string
            coord = coordinate_from_string(cell.coordinate)
            col_letter, row_number = coord[0], coord[1]
            
            # Get the corresponding cell from the computed values workbook.
            cell_value_obj = sheet_value[cell.coordinate]
            
            cell_data = {
                'cell_location': cell.coordinate,
                'column': col_letter,
                'row': row_number,
                'value': cell_value_obj.value,  # Calculated value from the data_only workbook.
                'formula': None,                # Full formula string (if present)
                'precedents': None,             # Logic for precedents can be implemented as needed.
                'dependencies': None,
                'column_name': None,
                'row_name': None
            }

            # If the cell contains a formula, update formula field and extract dependencies.
            if isinstance(cell.value, str) and cell.value.startswith('='):
                cell_data['formula'] = cell.value  # The full formula
                deps = extract_dependencies(cell.value)
                cell_data['dependencies'] = deps

            
            
            # Only add cells that have a value.
            if cell_data['value'] is not None:
                cells_data.append(cell_data)

    # Build a mapping from cell coordinates to their corresponding cell data dictionaries.
    cell_map = {cell['cell_location']: cell for cell in cells_data}
    # For each cell with dependencies, iterate over its dependencies and add this cell as a precedent in the referenced cell's data.
    for cell in cells_data:
        if cell.get('dependencies'):
            for dep in cell['dependencies']:
                if dep in cell_map:
                    if cell_map[dep]['precedents'] is None:
                        cell_map[dep]['precedents'] = []
                    cell_map[dep]['precedents'].append(cell['cell_location'])

    

    
    return cells_data

# %%
def query_openai(prompt):
    # Make sure your API key is set in the environment variable OPENAI_API_KEY
    api_key = os.getenv("OPENAI_API_KEY")
    if not api_key:
        sys.exit("Error: The OPENAI_API_KEY environment variable is not set.")

    # Create a client instance
    client = openai.OpenAI(api_key=api_key)
    
    # Make the API call using the new interface
    response = client.chat.completions.create(
        model="o3-mini",
        #model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": "You are an assistant that helps deduce spreadsheet headers."},
            {"role": "user", "content": prompt}
        ],
    )
    
    # Extract the content from the response
    return response.choices[0].message.content

# %%
file_name = "101-01-90-Minute-Case-Study-Otis-Complete.xlsx"

# %%
cells_info = load_excel_with_metadata(file_name)

# %%
prompt = build_prompt(cells_info)

# %%
answer = query_openai(prompt)

# %%
data = json.loads(answer)

# %%
# Initialize empty dictionaries to store the mapped data
row_names = {}
column_names = {}

# Map row and column names from data using cells_info locations
for i, cell_info in enumerate(cells_info):
    row = str(cell_info['row'])  # Convert row number to string since data keys are strings
    col = cell_info['column']
    
    # Look up row and column names from data
    if row in data['row_name']:
        cells_info[i]['row_name'] = data['row_name'][row]
    if col in data['column_name']:
        cells_info[i]['column_name'] = data['column_name'][col]

# %%
t = pd.DataFrame(cells_info)

# %%
t
# Out:
#     cell_location column  row                value               formula  \
# 0              B2      B    2             Drivers:                  None
# 1              C2      C    2  2019-12-31 00:00:00                  None
# 2              D2      D    2  2020-12-31 00:00:00       =EOMONTH(C2,12)
# 3              E2      E    2  2021-12-31 00:00:00       =EOMONTH(D2,12)
# 4              F2      F    2  2022-12-31 00:00:00       =EOMONTH(E2,12)
# ..            ...    ...  ...                  ...                   ...
# 742          F126      F  126               -475.0  =F109+F114+F122+F124
# 743          G126      G  126                 -0.0  =G109+G114+G122+G124
# 744          H126      H  126                  0.0  =H109+H114+H122+H124
# 745          I126      I  126                 -0.0  =I109+I114+I122+I124
# 746          J126      J  126                  0.0  =J109+J114+J122+J124
#
#     precedents              dependencies column_name             row_name
# 0         None                      None        None                 None
# 1         [D2]                      None  2019-12-31                 None
# 2         [E2]                      [C2]  2020-12-31                 None
# 3         [F2]                      [D2]  2021-12-31                 None
# 4         [G2]                      [E2]  2022-12-31                 None
# ..         ...                       ...         ...                  ...
# 742      [F77]  [F109, F114, F122, F124]  2022-12-31  Net Change in Cash:
# 743      [G77]  [G109, G114, G122, G124]  2023-12-31  Net Change in Cash:
# 744      [H77]  [H109, H114, H122, H124]  2024-12-31  Net Change in Cash:
# 745      [I77]  [I109, I114, I122, I124]  2025-12-31  Net Change in Cash:
# 746      [J77]  [J109, J114, J122, J124]  2026-12-31  Net Change in Cash:
#
# [747 rows x 9 columns]

# %%
cells_info
# Out:
# [{'cell_location': 'B2',
#   'column': 'B',
#   'row': 2,
#   'value': 'Drivers:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None},
#  {'cell_location': 'C2',
#   'column': 'C',
#   'row': 2,
#   'value': datetime.datetime(2019, 12, 31, 0, 0),
#   'formula': None,
#   'precedents': ['D2'],
#   'dependencies': None,
#   'column_name': '2019-12-31',
#   'row_name': None},
#  {'cell_location': 'D2',
#   'column': 'D',
#   'row': 2,
#   'value': datetime.datetime(2020, 12, 31, 0, 0),
#   'formula': '=EOMONTH(C2,12)',
#   'precedents': ['E2'],
#   'dependencies': ['C2'],
#   'column_name': '2020-12-31',
#   'row_name': None},
#  {'cell_location': 'E2',
#   'column': 'E',
#   'row': 2,
#   'value': datetime.datetime(2021, 12, 31, 0, 0),
#   'formula': '=EOMONTH(D2,12)',
#   'precedents': ['F2'],
#   'dependencies': ['D2'],
#   'column_name': '2021-12-31',
#   'row_name': None},
#  {'cell_location': 'F2',
#   'column': 'F',
#   'row': 2,
#   'value': datetime.datetime(2022, 12, 31, 0, 0),
#   'formula': '=EOMONTH(E2,12)',
#   'precedents': ['G2'],
#   'dependencies': ['E2'],
#   'column_name': '2022-12-31',
#   'row_name': None},
#  {'cell_location': 'G2',
#   'column': 'G',
#   'row': 2,
#   'value': datetime.datetime(2023, 12, 31, 0, 0),
#   'formula': '=EOMONTH(F2,12)',
#   'precedents': ['H2'],
#   'dependencies': ['F2'],
#   'column_name': '2023-12-31',
#   'row_name': None},
#  {'cell_location': 'H2',
#   'column': 'H',
#   'row': 2,
#   'value': datetime.datetime(2024, 12, 31, 0, 0),
#   'formula': '=EOMONTH(G2,12)',
#   'precedents': ['I2'],
#   'dependencies': ['G2'],
#   'column_name': '2024-12-31',
#   'row_name': None},
#  {'cell_location': 'I2',
#   'column': 'I',
#   'row': 2,
#   'value': datetime.datetime(2025, 12, 31, 0, 0),
#   'formula': '=EOMONTH(H2,12)',
#   'precedents': ['J2'],
#   'dependencies': ['H2'],
#   'column_name': '2025-12-31',
#   'row_name': None},
#  {'cell_location': 'J2',
#   'column': 'J',
#   'row': 2,
#   'value': datetime.datetime(2026, 12, 31, 0, 0),
#   'formula': '=EOMONTH(I2,12)',
#   'precedents': None,
#   'dependencies': ['I2'],
#   'column_name': '2026-12-31',
#   'row_name': None},
#  {'cell_location': 'B4',
#   'column': 'B',
#   'row': 4,
#   'value': 'New Equipment Market Size:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None},
#  {'cell_location': 'C4',
#   'column': 'C',
#   'row': 4,
#   'value': 35300,
#   'formula': '=C54/C7',
#   'precedents': ['D5'],
#   'dependencies': ['C54', 'C7'],
#   'column_name': '2019-12-31',
#   'row_name': None},
#  {'cell_location': 'D4',
#   'column': 'D',
#   'row': 4,
#   'value': 31594.11764705882,
#   'formula': '=D54/D7',
#   'precedents': ['D5', 'E5'],
#   'dependencies': ['D54', 'D7'],
#   'column_name': '2020-12-31',
#   'row_name': None},
#  {'cell_location': 'E4',
#   'column': 'E',
#   'row': 4,
#   'value': 35711.11111111111,
#   'formula': '=E54/E7',
#   'precedents': ['F4', 'E5'],
#   'dependencies': ['E54', 'E7'],
#   'column_name': '2021-12-31',
#   'row_name': None},
#  {'cell_location': 'F4',
#   'column': 'F',
#   'row': 4,
#   'value': 37496.666666666664,
#   'formula': '=E4*(1+F5)',
#   'precedents': ['G4', 'F54'],
#   'dependencies': ['E4', 'F5'],
#   'column_name': '2022-12-31',
#   'row_name': None},
#  {'cell_location': 'G4',
#   'column': 'G',
#   'row': 4,
#   'value': 39371.5,
#   'formula': '=F4*(1+G5)',
#   'precedents': ['H4', 'G54'],
#   'dependencies': ['F4', 'G5'],
#   'column_name': '2023-12-31',
#   'row_name': None},
#  {'cell_location': 'H4',
#   'column': 'H',
#   'row': 4,
#   'value': 40946.36,
#   'formula': '=G4*(1+H5)',
#   'precedents': ['I4', 'H54'],
#   'dependencies': ['G4', 'H5'],
#   'column_name': '2024-12-31',
#   'row_name': None},
#  {'cell_location': 'I4',
#   'column': 'I',
#   'row': 4,
#   'value': 42584.214400000004,
#   'formula': '=H4*(1+I5)',
#   'precedents': ['J4', 'I54'],
#   'dependencies': ['H4', 'I5'],
#   'column_name': '2025-12-31',
#   'row_name': None},
#  {'cell_location': 'J4',
#   'column': 'J',
#   'row': 4,
#   'value': 43861.740832,
#   'formula': '=I4*(1+J5)',
#   'precedents': ['J54'],
#   'dependencies': ['I4', 'J5'],
#   'column_name': '2026-12-31',
#   'row_name': None},
#  {'cell_location': 'B5',
#   'column': 'B',
#   'row': 5,
#   'value': 'Growth Rate:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None},
#  {'cell_location': 'D5',
#   'column': 'D',
#   'row': 5,
#   'value': -0.10498250291618072,
#   'formula': '=D4/C4-1',
#   'precedents': None,
#   'dependencies': ['D4', 'C4'],
#   'column_name': '2020-12-31',
#   'row_name': None},
#  {'cell_location': 'E5',
#   'column': 'E',
#   'row': 5,
#   'value': 0.1303088603405118,
#   'formula': '=E4/D4-1',
#   'precedents': None,
#   'dependencies': ['E4', 'D4'],
#   'column_name': '2021-12-31',
#   'row_name': None},
#  {'cell_location': 'F5',
#   'column': 'F',
#   'row': 5,
#   'value': 0.05,
#   'formula': None,
#   'precedents': ['F4'],
#   'dependencies': None,
#   'column_name': '2022-12-31',
#   'row_name': None},
#  {'cell_location': 'G5',
#   'column': 'G',
#   'row': 5,
#   'value': 0.05,
#   'formula': None,
#   'precedents': ['G4'],
#   'dependencies': None,
#   'column_name': '2023-12-31',
#   'row_name': None},
#  {'cell_location': 'H5',
#   'column': 'H',
#   'row': 5,
#   'value': 0.04,
#   'formula': None,
#   'precedents': ['H4'],
#   'dependencies': None,
#   'column_name': '2024-12-31',
#   'row_name': None},
#  {'cell_location': 'I5',
#   'column': 'I',
#   'row': 5,
#   'value': 0.04,
#   'formula': None,
#   'precedents': ['I4'],
#   'dependencies': None,
#   'column_name': '2025-12-31',
#   'row_name': None},
#  {'cell_location': 'J5',
#   'column': 'J',
#   'row': 5,
#   'value': 0.03,
#   'formula': None,
#   'precedents': ['J4'],
#   'dependencies': None,
#   'column_name': '2026-12-31',
#   'row_name': None},
#  {'cell_location': 'B7',
#   'column': 'B',
#   'row': 7,
#   'value': 'New Equipment Market Share:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None},
#  {'cell_location': 'C7',
#   'column': 'C',
#   'row': 7,
#   'value': 0.16,
#   'formula': None,
#   'precedents': ['C4'],
#   'dependencies': None,
#   'column_name': '2019-12-31',
#   'row_name': None},
#  {'cell_location': 'D7',
#   'column': 'D',
#   'row': 7,
#   'value': 0.17,
#   'formula': None,
#   'precedents': ['D4'],
#   'dependencies': None,
#   'column_name': '2020-12-31',
#   'row_name': None},
#  {'cell_location': 'E7',
#   'column': 'E',
#   'row': 7,
#   'value': 0.18,
#   'formula': None,
#   'precedents': ['E4'],
#   'dependencies': None,
#   'column_name': '2021-12-31',
#   'row_name': None},
#  {'cell_location': 'F7',
#   'column': 'F',
#   'row': 7,
#   'value': 0.18,
#   'formula': None,
#   'precedents': ['F54'],
#   'dependencies': None,
#   'column_name': '2022-12-31',
#   'row_name': None},
#  {'cell_location': 'G7',
#   'column': 'G',
#   'row': 7,
#   'value': 0.182,
#   'formula': None,
#   'precedents': ['G54'],
#   'dependencies': None,
#   'column_name': '2023-12-31',
#   'row_name': None},
#  {'cell_location': 'H7',
#   'column': 'H',
#   'row': 7,
#   'value': 0.184,
#   'formula': None,
#   'precedents': ['H54'],
#   'dependencies': None,
#   'column_name': '2024-12-31',
#   'row_name': None},
#  {'cell_location': 'I7',
#   'column': 'I',
#   'row': 7,
#   'value': 0.185,
#   'formula': None,
#   'precedents': ['I54'],
#   'dependencies': None,
#   'column_name': '2025-12-31',
#   'row_name': None},
#  {'cell_location': 'J7',
#   'column': 'J',
#   'row': 7,
#   'value': 0.185,
#   'formula': None,
#   'precedents': ['J54'],
#   'dependencies': None,
#   'column_name': '2026-12-31',
#   'row_name': None},
#  {'cell_location': 'B9',
#   'column': 'B',
#   'row': 9,
#   'value': 'Service Units (Maintenance):',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None},
#  {'cell_location': 'C9',
#   'column': 'C',
#   'row': 9,
#   'value': 2,
#   'formula': None,
#   'precedents': ['D10', 'C12'],
#   'dependencies': None,
#   'column_name': '2019-12-31',
#   'row_name': None},
#  {'cell_location': 'D9',
#   'column': 'D',
#   'row': 9,
#   'value': 2.1,
#   'formula': None,
#   'precedents': ['D10', 'E10', 'D12'],
#   'dependencies': None,
#   'column_name': '2020-12-31',
#   'row_name': None},
#  {'cell_location': 'E9',
#   'column': 'E',
#   'row': 9,
#   'value': 2.15,
#   'formula': None,
#   'precedents': ['F9', 'E10', 'E12'],
#   'dependencies': None,
#   'column_name': '2021-12-31',
#   'row_name': None},
#  {'cell_location': 'F9',
#   'column': 'F',
#   'row': 9,
#   'value': 2.2145,
#   'formula': '=E9*(1+F10)',
#   'precedents': ['G9', 'F55'],
#   'dependencies': ['E9', 'F10'],
#   'column_name': '2022-12-31',
#   'row_name': None},
#  {'cell_location': 'G9',
#   'column': 'G',
#   'row': 9,
#   'value': 2.2809350000000004,
#   'formula': '=F9*(1+G10)',
#   'precedents': ['H9', 'G55'],
#   'dependencies': ['F9', 'G10'],
#   'column_name': '2023-12-31',
#   'row_name': None},
#  {'cell_location': 'H9',
#   'column': 'H',
#   'row': 9,
#   'value': 2.3493630500000005,
#   'formula': '=G9*(1+H10)',
#   'precedents': ['I9', 'H55'],
#   'dependencies': ['G9', 'H10'],
#   'column_name': '2024-12-31',
#   'row_name': None},
#  {'cell_location': 'I9',
#   'column': 'I',
#   'row': 9,
#   'value': 2.4198439415000004,
#   'formula': '=H9*(1+I10)',
#   'precedents': ['J9', 'I55'],
#   'dependencies': ['H9', 'I10'],
#   'column_name': '2025-12-31',
#   'row_name': None},
#  {'cell_location': 'J9',
#   'column': 'J',
#   'row': 9,
#   'value': 2.4924392597450002,
#   'formula': '=I9*(1+J10)',
#   'precedents': ['J55'],
#   'dependencies': ['I9', 'J10'],
#   'column_name': '2026-12-31',
#   'row_name': None},
#  {'cell_location': 'B10',
#   'column': 'B',
#   'row': 10,
#   'value': 'Growth Rate:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None},
#  {'cell_location': 'D10',
#   'column': 'D',
#   'row': 10,
#   'value': 0.050000000000000044,
#   'formula': '=D9/C9-1',
#   'precedents': None,
#   'dependencies': ['D9', 'C9'],
#   'column_name': '2020-12-31',
#   'row_name': None},
#  {'cell_location': 'E10',
#   'column': 'E',
#   'row': 10,
#   'value': 0.023809523809523725,
#   'formula': '=E9/D9-1',
#   'precedents': None,
#   'dependencies': ['E9', 'D9'],
#   'column_name': '2021-12-31',
#   'row_name': None},
#  {'cell_location': 'F10',
#   'column': 'F',
#   'row': 10,
#   'value': 0.03,
#   'formula': None,
#   'precedents': ['F9'],
#   'dependencies': None,
#   'column_name': '2022-12-31',
#   'row_name': None},
#  {'cell_location': 'G10',
#   'column': 'G',
#   'row': 10,
#   'value': 0.03,
#   'formula': None,
#   'precedents': ['G9'],
#   'dependencies': None,
#   'column_name': '2023-12-31',
#   'row_name': None},
#  {'cell_location': 'H10',
#   'column': 'H',
#   'row': 10,
#   'value': 0.03,
#   'formula': None,
#   'precedents': ['H9'],
#   'dependencies': None,
#   'column_name': '2024-12-31',
#   'row_name': None},
#  {'cell_location': 'I10',
#   'column': 'I',
#   'row': 10,
#   'value': 0.03,
#   'formula': None,
#   'precedents': ['I9'],
#   'dependencies': None,
#   'column_name': '2025-12-31',
#   'row_name': None},
#  {'cell_location': 'J10',
#   'column': 'J',
#   'row': 10,
#   'value': 0.03,
#   'formula': None,
#   'precedents': ['J9'],
#   'dependencies': None,
#   'column_name': '2026-12-31',
#   'row_name': None},
#  {'cell_location': 'B12',
#   'column': 'B',
#   'row': 12,
#   'value': 'Revenue per Service Unit:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None},
#  {'cell_location': 'C12',
#   'column': 'C',
#   'row': 12,
#   'value': 3735,
#   'formula': '=C55/C9',
#   'precedents': ['D13'],
#   'dependencies': ['C55', 'C9'],
#   'column_name': '2019-12-31',
#   'row_name': None},
#  {'cell_location': 'D12',
#   'column': 'D',
#   'row': 12,
#   'value': 3516.6666666666665,
#   'formula': '=D55/D9',
#   'precedents': ['D13', 'E13'],
#   'dependencies': ['D55', 'D9'],
#   'column_name': '2020-12-31',
#   'row_name': None},
#  {'cell_location': 'E12',
#   'column': 'E',
#   'row': 12,
#   'value': 3660.46511627907,
#   'formula': '=E55/E9',
#   'precedents': ['F12', 'E13'],
#   'dependencies': ['E55', 'E9'],
#   'column_name': '2021-12-31',
#   'row_name': None},
#  {'cell_location': 'F12',
#   'column': 'F',
#   'row': 12,
#   'value': 3806.8837209302333,
#   'formula': '=E12*(1+F13)',
#   'precedents': ['G12', 'F55'],
#   'dependencies': ['E12', 'F13'],
#   'column_name': '2022-12-31',
#   'row_name': None},
#  {'cell_location': 'G12',
#   'column': 'G',
#   'row': 12,
#   'value': 3940.124651162791,
#   'formula': '=F12*(1+G13)',
#   'precedents': ['H12', 'G55'],
#   'dependencies': ['F12', 'G13'],
#   'column_name': '2023-12-31',
#   'row_name': None},
#  {'cell_location': 'H12',
#   'column': 'H',
#   'row': 12,
#   'value': 4078.029013953488,
#   'formula': '=G12*(1+H13)',
#   'precedents': ['I12', 'H55'],
#   'dependencies': ['G12', 'H13'],
#   'column_name': '2024-12-31',
#   'row_name': None},
#  {'cell_location': 'I12',
#   'column': 'I',
#   'row': 12,
#   'value': 4200.369884372093,
#   'formula': '=H12*(1+I13)',
#   'precedents': ['J12', 'I55'],
#   'dependencies': ['H12', 'I13'],
#   'column_name': '2025-12-31',
#   'row_name': None},
#  {'cell_location': 'J12',
#   'column': 'J',
#   'row': 12,
#   'value': 4326.380980903256,
#   'formula': '=I12*(1+J13)',
#   'precedents': ['J55'],
#   'dependencies': ['I12', 'J13'],
#   'column_name': '2026-12-31',
#   'row_name': None},
#  {'cell_location': 'B13',
#   'column': 'B',
#   'row': 13,
#   'value': 'Growth Rate:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None},
#  {'cell_location': 'D13',
#   'column': 'D',
#   'row': 13,
#   'value': -0.058456046407853623,
#   'formula': '=D12/C12-1',
#   'precedents': None,
#   'dependencies': ['D12', 'C12'],
#   'column_name': '2020-12-31',
#   'row_name': None},
#  {'cell_location': 'E13',
#   'column': 'E',
#   'row': 13,
#   'value': 0.04089055439215272,
#   'formula': '=E12/D12-1',
#   'precedents': None,
#   'dependencies': ['E12', 'D12'],
#   'column_name': '2021-12-31',
#   'row_name': None},
#  {'cell_location': 'F13',
#   'column': 'F',
#   'row': 13,
#   'value': 0.04,
#   'formula': None,
#   'precedents': ['F12'],
#   'dependencies': None,
#   'column_name': '2022-12-31',
#   'row_name': None},
#  {'cell_location': 'G13',
#   'column': 'G',
#   'row': 13,
#   'value': 0.035,
#   'formula': None,
#   'precedents': ['G12'],
#   'dependencies': None,
#   'column_name': '2023-12-31',
#   'row_name': None},
#  {'cell_location': 'H13',
#   'column': 'H',
#   'row': 13,
#   'value': 0.035,
#   'formula': None,
#   'precedents': ['H12'],
#   'dependencies': None,
#   'column_name': '2024-12-31',
#   'row_name': None},
#  {'cell_location': 'I13',
#   'column': 'I',
#   'row': 13,
#   'value': 0.03,
#   'formula': None,
#   'precedents': ['I12'],
#   'dependencies': None,
#   'column_name': '2025-12-31',
#   'row_name': None},
#  {'cell_location': 'J13',
#   'column': 'J',
#   'row': 13,
#   'value': 0.03,
#   'formula': None,
#   'precedents': ['J12'],
#   'dependencies': None,
#   'column_name': '2026-12-31',
#   'row_name': None},
#  {'cell_location': 'B15',
#   'column': 'B',
#   'row': 15,
#   'value': 'Product - COGS % Revenue:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None},
#  {'cell_location': 'C15',
#   'column': 'C',
#   'row': 15,
#   'value': 0.8215297450424929,
#   'formula': '=-C58/C54',
#   'precedents': ['F15'],
#   'dependencies': ['C58', 'C54'],
#   'column_name': '2019-12-31',
#   'row_name': None},
#  {'cell_location': 'D15',
#   'column': 'D',
#   'row': 15,
#   'value': 0.8264755166635636,
#   'formula': '=-D58/D54',
#   'precedents': None,
#   'dependencies': ['D58', 'D54'],
#   'column_name': '2020-12-31',
#   'row_name': None},
#  {'cell_location': 'E15',
#   'column': 'E',
#   'row': 15,
#   'value': 0.823428749222153,
#   'formula': '=-E58/E54',
#   'precedents': ['F15'],
#   'dependencies': ['E58', 'E54'],
#   'column_name': '2021-12-31',
#   'row_name': None},
#  {'cell_location': 'F15',
#   'column': 'F',
#   'row': 15,
#   'value': 0.8238113369760698,
#   'formula': '=AVERAGE(C15:E15)',
#   'precedents': ['G15', 'F58'],
#   'dependencies': ['C15', 'E15'],
#   'column_name': '2022-12-31',
#   'row_name': None},
#  {'cell_location': 'G15',
#   'column': 'G',
#   'row': 15,
#   'value': 0.8238113369760698,
#   'formula': '=F15',
#   'precedents': ['H15', 'G58'],
#   'dependencies': ['F15'],
#   'column_name': '2023-12-31',
#   'row_name': None},
#  {'cell_location': 'H15',
#   'column': 'H',
#   'row': 15,
#   'value': 0.8238113369760698,
#   'formula': '=G15',
#   'precedents': ['I15', 'H58'],
#   'dependencies': ['G15'],
#   'column_name': '2024-12-31',
#   'row_name': None},
#  {'cell_location': 'I15',
#   'column': 'I',
#   'row': 15,
#   'value': 0.8238113369760698,
#   'formula': '=H15',
#   'precedents': ['J15', 'I58'],
#   'dependencies': ['H15'],
#   'column_name': '2025-12-31',
#   'row_name': None},
#  {'cell_location': 'J15',
#   'column': 'J',
#   'row': 15,
#   'value': 0.8238113369760698,
#   'formula': '=I15',
#   'precedents': ['J58'],
#   'dependencies': ['I15'],
#   'column_name': '2026-12-31',
#   'row_name': None},
#  {'cell_location': 'B16',
#   'column': 'B',
#   'row': 16,
#   'value': 'Service - COGS % Revenue:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None},
#  {'cell_location': 'C16',
#   'column': 'C',
#   'row': 16,
#   'value': 0.6227576974564927,
#   'formula': '=-C59/C55',
#   'precedents': ['F16'],
#   'dependencies': ['C59', 'C55'],
#   'column_name': '2019-12-31',
#   'row_name': None},
#  {'cell_location': 'D16',
#   'column': 'D',
#   'row': 16,
#   'value': 0.6144888287068382,
#   'formula': '=-D59/D55',
#   'precedents': None,
#   'dependencies': ['D59', 'D55'],
#   'column_name': '2020-12-31',
#   'row_name': None},
#  {'cell_location': 'E16',
#   'column': 'E',
#   'row': 16,
#   'value': 0.61143583227446,
#   'formula': '=-E59/E55',
#   'precedents': ['F16'],
#   'dependencies': ['E59', 'E55'],
#   'column_name': '2021-12-31',
#   'row_name': None},
#  {'cell_location': 'F16',
#   'column': 'F',
#   'row': 16,
#   'value': 0.6162274528125969,
#   'formula': '=AVERAGE(C16:E16)',
#   'precedents': ['G16', 'F59'],
#   'dependencies': ['C16', 'E16'],
#   'column_name': '2022-12-31',
#   'row_name': None},
#  {'cell_location': 'G16',
#   'column': 'G',
#   'row': 16,
#   'value': 0.6162274528125969,
#   'formula': '=F16',
#   'precedents': ['H16', 'G59'],
#   'dependencies': ['F16'],
#   'column_name': '2023-12-31',
#   'row_name': None},
#  {'cell_location': 'H16',
#   'column': 'H',
#   'row': 16,
#   'value': 0.6162274528125969,
#   'formula': '=G16',
#   'precedents': ['I16', 'H59'],
#   'dependencies': ['G16'],
#   'column_name': '2024-12-31',
#   'row_name': None},
#  {'cell_location': 'I16',
#   'column': 'I',
#   'row': 16,
#   'value': 0.6162274528125969,
#   'formula': '=H16',
#   'precedents': ['J16', 'I59'],
#   'dependencies': ['H16'],
#   'column_name': '2025-12-31',
#   'row_name': None},
#  {'cell_location': 'J16',
#   'column': 'J',
#   'row': 16,
#   'value': 0.6162274528125969,
#   'formula': '=I16',
#   'precedents': ['J59'],
#   'dependencies': ['I16'],
#   'column_name': '2026-12-31',
#   'row_name': None},
#  {'cell_location': 'B17',
#   'column': 'B',
#   'row': 17,
#   'value': 'OpEx % Revenue:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None},
#  {'cell_location': 'C17',
#   'column': 'C',
#   'row': 17,
#   'value': 0.15040402500381156,
#   'formula': '=-C60/C56',
#   'precedents': ['F17'],
#   'dependencies': ['C60', 'C56'],
#   'column_name': '2019-12-31',
#   'row_name': None},
#  {'cell_location': 'D17',
#   'column': 'D',
#   'row': 17,
#   'value': 0.1627469426152399,
#   'formula': '=-D60/D56',
#   'precedents': None,
#   'dependencies': ['D60', 'D56'],
#   'column_name': '2020-12-31',
#   'row_name': None},
#  {'cell_location': 'E17',
#   'column': 'E',
#   'row': 17,
#   'value': 0.1473632675898727,
#   'formula': '=-E60/E56',
#   'precedents': ['F17'],
#   'dependencies': ['E60', 'E56'],
#   'column_name': '2021-12-31',
#   'row_name': None},
#  {'cell_location': 'F17',
#   'column': 'F',
#   'row': 17,
#   'value': 0.1535047450696414,
#   'formula': '=AVERAGE(C17:E17)',
#   'precedents': ['G17', 'F60'],
#   'dependencies': ['C17', 'E17'],
#   'column_name': '2022-12-31',
#   'row_name': None},
#  {'cell_location': 'G17',
#   'column': 'G',
#   'row': 17,
#   'value': 0.1535047450696414,
#   'formula': '=F17',
#   'precedents': ['H17', 'G60'],
#   'dependencies': ['F17'],
#   'column_name': '2023-12-31',
#   'row_name': None},
#  {'cell_location': 'H17',
#   'column': 'H',
#   'row': 17,
#   'value': 0.1535047450696414,
#   'formula': '=G17',
#   'precedents': ['I17', 'H60'],
#   'dependencies': ['G17'],
#   'column_name': '2024-12-31',
#   'row_name': None},
#  {'cell_location': 'I17',
#   'column': 'I',
#   'row': 17,
#   'value': 0.1535047450696414,
#   'formula': '=H17',
#   'precedents': ['J17', 'I60'],
#   'dependencies': ['H17'],
#   'column_name': '2025-12-31',
#   'row_name': None},
#  {'cell_location': 'J17',
#   'column': 'J',
#   'row': 17,
#   'value': 0.1535047450696414,
#   'formula': '=I17',
#   'precedents': ['J60'],
#   'dependencies': ['I17'],
#   'column_name': '2026-12-31',
#   'row_name': None},
#  {'cell_location': 'B19',
#   'column': 'B',
#   'row': 19,
#   'value': 'Tax Rate:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None},
#  {'cell_location': 'C19',
#   'column': 'C',
#   'row': 19,
#   'value': 0.3191832348199892,
#   'formula': '=-C68/C66',
#   'precedents': ['F19'],
#   'dependencies': ['C68', 'C66'],
#   'column_name': '2019-12-31',
#   'row_name': None},
#  {'cell_location': 'D19',
#   'column': 'D',
#   'row': 19,
#   'value': 0.3011250827266711,
#   'formula': '=-D68/D66',
#   'precedents': None,
#   'dependencies': ['D68', 'D66'],
#   'column_name': '2020-12-31',
#   'row_name': None},
#  {'cell_location': 'E19',
#   'column': 'E',
#   'row': 19,
#   'value': 0.2758796532381438,
#   'formula': '=-E68/E66',
#   'precedents': ['F19'],
#   'dependencies': ['E68', 'E66'],
#   'column_name': '2021-12-31',
#   'row_name': None},
#  {'cell_location': 'F19',
#   'column': 'F',
#   'row': 19,
#   'value': 0.2987293235949347,
#   'formula': '=AVERAGE(C19:E19)',
#   'precedents': ['G19', 'F68'],
#   'dependencies': ['C19', 'E19'],
#   'column_name': '2022-12-31',
#   'row_name': None},
#  {'cell_location': 'G19',
#   'column': 'G',
#   'row': 19,
#   'value': 0.2987293235949347,
#   'formula': '=F19',
#   'precedents': ['H19', 'G68'],
#   'dependencies': ['F19'],
#   'column_name': '2023-12-31',
#   'row_name': None},
#  {'cell_location': 'H19',
#   'column': 'H',
#   'row': 19,
#   'value': 0.2987293235949347,
#   'formula': '=G19',
#   'precedents': ['I19', 'H68'],
#   'dependencies': ['G19'],
#   'column_name': '2024-12-31',
#   'row_name': None},
#  {'cell_location': 'I19',
#   'column': 'I',
#   'row': 19,
#   'value': 0.2987293235949347,
#   'formula': '=H19',
#   'precedents': ['J19', 'I68'],
#   'dependencies': ['H19'],
#   'column_name': '2025-12-31',
#   'row_name': None},
#  {'cell_location': 'J19',
#   'column': 'J',
#   'row': 19,
#   'value': 0.2987293235949347,
#   'formula': '=I19',
#   'precedents': ['J68'],
#   'dependencies': ['I19'],
#   'column_name': '2026-12-31',
#   'row_name': None},
#  {'cell_location': 'B20',
#   'column': 'B',
#   'row': 20,
#   'value': 'NCI Net Income % Total:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None},
#  {'cell_location': 'C20',
#   'column': 'C',
#   'row': 20,
#   'value': 0.11917916337805841,
#   'formula': '=-C71/C70',
#   'precedents': ['F20'],
#   'dependencies': ['C71', 'C70'],
#   'column_name': '2019-12-31',
#   'row_name': None},
#  {'cell_location': 'D20',
#   'column': 'D',
#   'row': 20,
#   'value': 0.14204545454545456,
#   'formula': '=-D71/D70',
#   'precedents': None,
#   'dependencies': ['D71', 'D70'],
#   'column_name': '2020-12-31',
#   'row_name': None},
#  {'cell_location': 'E20',
#   'column': 'E',
#   'row': 20,
#   'value': 0.12253521126760564,
#   'formula': '=-E71/E70',
#   'precedents': ['F20'],
#   'dependencies': ['E71', 'E70'],
#   'column_name': '2021-12-31',
#   'row_name': None},
#  {'cell_location': 'F20',
#   'column': 'F',
#   'row': 20,
#   'value': 0.12791994306370622,
#   'formula': '=AVERAGE(C20:E20)',
#   'precedents': ['G20', 'F71'],
#   'dependencies': ['C20', 'E20'],
#   'column_name': '2022-12-31',
#   'row_name': None},
#  {'cell_location': 'G20',
#   'column': 'G',
#   'row': 20,
#   'value': 0.12791994306370622,
#   'formula': '=F20',
#   'precedents': ['H20', 'G71'],
#   'dependencies': ['F20'],
#   'column_name': '2023-12-31',
#   'row_name': None},
#  {'cell_location': 'H20',
#   'column': 'H',
#   'row': 20,
#   'value': 0.12791994306370622,
#   'formula': '=G20',
#   'precedents': ['I20', 'H71'],
#   'dependencies': ['G20'],
#   'column_name': '2024-12-31',
#   'row_name': None},
#  {'cell_location': 'I20',
#   'column': 'I',
#   'row': 20,
#   'value': 0.12791994306370622,
#   'formula': '=H20',
#   'precedents': ['J20', 'I71'],
#   'dependencies': ['H20'],
#   'column_name': '2025-12-31',
#   'row_name': None},
#  {'cell_location': 'J20',
#   'column': 'J',
#   'row': 20,
#   'value': 0.12791994306370622,
#   'formula': '=I20',
#   'precedents': ['J71'],
#   'dependencies': ['I20'],
#   'column_name': '2026-12-31',
#   'row_name': None},
#  {'cell_location': 'B22',
#   'column': 'B',
#   'row': 22,
#   'value': 'Accounts Receivable % Revenue:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None},
#  {'cell_location': 'D22',
#   'column': 'D',
#   'row': 22,
#   'value': 0.24678582627783005,
#   'formula': '=D78/D56',
#   'precedents': None,
#   'dependencies': ['D78', 'D56'],
#   'column_name': '2020-12-31',
#   'row_name': None},
#  {'cell_location': 'E22',
#   'column': 'E',
#   'row': 22,
#   'value': 0.22604560078332633,
#   'formula': '=E78/E56',
#   'precedents': ['F22'],
#   'dependencies': ['E78', 'E56'],
#   'column_name': '2021-12-31',
#   'row_name': None},
#  {'cell_location': 'F22',
#   'column': 'F',
#   'row': 22,
#   'value': 0.2364157135305782,
#   'formula': '=AVERAGE(C22:E22)',
#   'precedents': ['G22', 'F78'],
#   'dependencies': ['C22', 'E22'],
#   'column_name': '2022-12-31',
#   'row_name': None},
#  {'cell_location': 'G22',
#   'column': 'G',
#   'row': 22,
#   'value': 0.2364157135305782,
#   'formula': '=F22',
#   'precedents': ['H22', 'G78'],
#   'dependencies': ['F22'],
#   'column_name': '2023-12-31',
#   'row_name': None},
#  {'cell_location': 'H22',
#   'column': 'H',
#   'row': 22,
#   'value': 0.2364157135305782,
#   'formula': '=G22',
#   'precedents': ['I22', 'H78'],
#   'dependencies': ['G22'],
#   'column_name': '2024-12-31',
#   'row_name': None},
#  {'cell_location': 'I22',
#   'column': 'I',
#   'row': 22,
#   'value': 0.2364157135305782,
#   'formula': '=H22',
#   'precedents': ['J22', 'I78'],
#   'dependencies': ['H22'],
#   'column_name': '2025-12-31',
#   'row_name': None},
#  {'cell_location': 'J22',
#   'column': 'J',
#   'row': 22,
#   'value': 0.2364157135305782,
#   'formula': '=I22',
#   'precedents': ['J78'],
#   'dependencies': ['I22'],
#   'column_name': '2026-12-31',
#   'row_name': None},
#  {'cell_location': 'B23',
#   'column': 'B',
#   'row': 23,
#   'value': 'Inventory & Other % COGS:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None},
#  {'cell_location': 'D23',
#   'column': 'D',
#   'row': 23,
#   'value': 0.1722178901637518,
#   'formula': '=-D79/SUM(D58:D59)',
#   'precedents': None,
#   'dependencies': ['D79', 'D58', 'D59'],
#   'column_name': '2020-12-31',
#   'row_name': None},
#  {'cell_location': 'E23',
#   'column': 'E',
#   'row': 23,
#   'value': 0.15378525482434438,
#   'formula': '=-E79/SUM(E58:E59)',
#   'precedents': ['F23'],
#   'dependencies': ['E79', 'E58', 'E59'],
#   'column_name': '2021-12-31',
#   'row_name': None},
#  {'cell_location': 'F23',
#   'column': 'F',
#   'row': 23,
#   'value': 0.1630015724940481,
#   'formula': '=AVERAGE(C23:E23)',
#   'precedents': ['G23', 'F79'],
#   'dependencies': ['C23', 'E23'],
#   'column_name': '2022-12-31',
#   'row_name': None},
#  {'cell_location': 'G23',
#   'column': 'G',
#   'row': 23,
#   'value': 0.1630015724940481,
#   'formula': '=F23',
#   'precedents': ['H23', 'G79'],
#   'dependencies': ['F23'],
#   'column_name': '2023-12-31',
#   'row_name': None},
#  {'cell_location': 'H23',
#   'column': 'H',
#   'row': 23,
#   'value': 0.1630015724940481,
#   'formula': '=G23',
#   'precedents': ['I23', 'H79'],
#   'dependencies': ['G23'],
#   'column_name': '2024-12-31',
#   'row_name': None},
#  {'cell_location': 'I23',
#   'column': 'I',
#   'row': 23,
#   'value': 0.1630015724940481,
#   'formula': '=H23',
#   'precedents': ['J23', 'I79'],
#   'dependencies': ['H23'],
#   'column_name': '2025-12-31',
#   'row_name': None},
#  {'cell_location': 'J23',
#   'column': 'J',
#   'row': 23,
#   'value': 0.1630015724940481,
#   'formula': '=I23',
#   'precedents': ['J79'],
#   'dependencies': ['I23'],
#   'column_name': '2026-12-31',
#   'row_name': None},
#  {'cell_location': 'B24',
#   'column': 'B',
#   'row': 24,
#   'value': 'Op. Lease Assets % OpEx:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None},
#  {'cell_location': 'D24',
#   'column': 'D',
#   'row': 24,
#   'value': 0.2610789980732177,
#   'formula': '=-D81/D60',
#   'precedents': None,
#   'dependencies': ['D81', 'D60'],
#   'column_name': '2020-12-31',
#   'row_name': None},
#  {'cell_location': 'E24',
#   'column': 'E',
#   'row': 24,
#   'value': 0.24964404366397722,
#   'formula': '=-E81/E60',
#   'precedents': ['F24'],
#   'dependencies': ['E81', 'E60'],
#   'column_name': '2021-12-31',
#   'row_name': None},
#  {'cell_location': 'F24',
#   'column': 'F',
#   'row': 24,
#   'value': 0.2553615208685975,
#   'formula': '=AVERAGE(C24:E24)',
#   'precedents': ['G24', 'F81'],
#   'dependencies': ['C24', 'E24'],
#   'column_name': '2022-12-31',
#   'row_name': None},
#  {'cell_location': 'G24',
#   'column': 'G',
#   'row': 24,
#   'value': 0.2553615208685975,
#   'formula': '=F24',
#   'precedents': ['H24', 'G81'],
#   'dependencies': ['F24'],
#   'column_name': '2023-12-31',
#   'row_name': None},
#  {'cell_location': 'H24',
#   'column': 'H',
#   'row': 24,
#   'value': 0.2553615208685975,
#   'formula': '=G24',
#   'precedents': ['I24', 'H81'],
#   'dependencies': ['G24'],
#   'column_name': '2024-12-31',
#   'row_name': None},
#  {'cell_location': 'I24',
#   'column': 'I',
#   'row': 24,
#   'value': 0.2553615208685975,
#   'formula': '=H24',
#   'precedents': ['J24', 'I81'],
#   'dependencies': ['H24'],
#   'column_name': '2025-12-31',
#   'row_name': None},
#  {'cell_location': 'J24',
#   'column': 'J',
#   'row': 24,
#   'value': 0.2553615208685975,
#   'formula': '=I24',
#   'precedents': ['J81'],
#   'dependencies': ['I24'],
#   'column_name': '2026-12-31',
#   'row_name': None},
#  {'cell_location': 'B26',
#   'column': 'B',
#   'row': 26,
#   'value': 'Accounts Payable % COGS:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None},
#  {'cell_location': 'D26',
#   'column': 'D',
#   'row': 26,
#   'value': 0.1618580817645093,
#   'formula': '=-D86/SUM(D58:D59)',
#   'precedents': None,
#   'dependencies': ['D86', 'D58', 'D59'],
#   'column_name': '2020-12-31',
#   'row_name': None},
#  {'cell_location': 'E26',
#   'column': 'E',
#   'row': 26,
#   'value': 0.15398317664522512,
#   'formula': '=-E86/SUM(E58:E59)',
#   'precedents': ['F26'],
#   'dependencies': ['E86', 'E58', 'E59'],
#   'column_name': '2021-12-31',
#   'row_name': None},
#  {'cell_location': 'F26',
#   'column': 'F',
#   'row': 26,
#   'value': 0.1579206292048672,
#   'formula': '=AVERAGE(C26:E26)',
#   'precedents': ['G26', 'F86'],
#   'dependencies': ['C26', 'E26'],
#   'column_name': '2022-12-31',
#   'row_name': None},
#  {'cell_location': 'G26',
#   'column': 'G',
#   'row': 26,
#   'value': 0.1579206292048672,
#   'formula': '=F26',
#   'precedents': ['H26', 'G86'],
#   'dependencies': ['F26'],
#   'column_name': '2023-12-31',
#   'row_name': None},
#  {'cell_location': 'H26',
#   'column': 'H',
#   'row': 26,
#   'value': 0.1579206292048672,
#   'formula': '=G26',
#   'precedents': ['I26', 'H86'],
#   'dependencies': ['G26'],
#   'column_name': '2024-12-31',
#   'row_name': None},
#  {'cell_location': 'I26',
#   'column': 'I',
#   'row': 26,
#   'value': 0.1579206292048672,
#   'formula': '=H26',
#   'precedents': ['J26', 'I86'],
#   'dependencies': ['H26'],
#   'column_name': '2025-12-31',
#   'row_name': None},
#  {'cell_location': 'J26',
#   'column': 'J',
#   'row': 26,
#   'value': 0.1579206292048672,
#   'formula': '=I26',
#   'precedents': ['J86'],
#   'dependencies': ['I26'],
#   'column_name': '2026-12-31',
#   'row_name': None},
#  {'cell_location': 'B27',
#   'column': 'B',
#   'row': 27,
#   'value': 'Accrued Liabilities % Total Expenses:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None},
#  {'cell_location': 'D27',
#   'column': 'D',
#   'row': 27,
#   'value': 0.1788654663892156,
#   'formula': '=-D87/SUM(D58:D60)',
#   'precedents': None,
#   'dependencies': ['D87', 'D58', 'D60'],
#   'column_name': '2020-12-31',
#   'row_name': None},
#  {'cell_location': 'E27',
#   'column': 'E',
#   'row': 27,
#   'value': 0.16320013101867015,
#   'formula': '=-E87/SUM(E58:E60)',
#   'precedents': ['F27'],
#   'dependencies': ['E87', 'E58', 'E60'],
#   'column_name': '2021-12-31',
#   'row_name': None},
#  {'cell_location': 'F27',
#   'column': 'F',
#   'row': 27,
#   'value': 0.1710327987039429,
#   'formula': '=AVERAGE(C27:E27)',
#   'precedents': ['G27', 'F87'],
#   'dependencies': ['C27', 'E27'],
#   'column_name': '2022-12-31',
#   'row_name': None},
#  {'cell_location': 'G27',
#   'column': 'G',
#   'row': 27,
#   'value': 0.1710327987039429,
#   'formula': '=F27',
#   'precedents': ['H27', 'G87'],
#   'dependencies': ['F27'],
#   'column_name': '2023-12-31',
#   'row_name': None},
#  {'cell_location': 'H27',
#   'column': 'H',
#   'row': 27,
#   'value': 0.1710327987039429,
#   'formula': '=G27',
#   'precedents': ['I27', 'H87'],
#   'dependencies': ['G27'],
#   'column_name': '2024-12-31',
#   'row_name': None},
#  {'cell_location': 'I27',
#   'column': 'I',
#   'row': 27,
#   'value': 0.1710327987039429,
#   'formula': '=H27',
#   'precedents': ['J27', 'I87'],
#   'dependencies': ['H27'],
#   'column_name': '2025-12-31',
#   'row_name': None},
#  {'cell_location': 'J27',
#   'column': 'J',
#   'row': 27,
#   'value': 0.1710327987039429,
#   'formula': '=I27',
#   'precedents': ['J87'],
#   'dependencies': ['I27'],
#   'column_name': '2026-12-31',
#   'row_name': None},
#  {'cell_location': 'B28',
#   'column': 'B',
#   'row': 28,
#   'value': 'Contract Liabilities % Total Expenses:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None},
#  {'cell_location': 'D28',
#   'column': 'D',
#   'row': 28,
#   'value': 0.2299828100968063,
#   'formula': '=-D88/SUM(D58:D60)',
#   'precedents': None,
#   'dependencies': ['D88', 'D58', 'D60'],
#   'column_name': '2020-12-31',
#   'row_name': None},
#  {'cell_location': 'E28',
#   'column': 'E',
#   'row': 28,
#   'value': 0.21896495250573206,
#   'formula': '=-E88/SUM(E58:E60)',
#   'precedents': ['F28'],
#   'dependencies': ['E88', 'E58', 'E60'],
#   'column_name': '2021-12-31',
#   'row_name': None},
#  {'cell_location': 'F28',
#   'column': 'F',
#   'row': 28,
#   'value': 0.22447388130126916,
#   'formula': '=AVERAGE(C28:E28)',
#   'precedents': ['G28', 'F88'],
#   'dependencies': ['C28', 'E28'],
#   'column_name': '2022-12-31',
#   'row_name': None},
#  {'cell_location': 'G28',
#   'column': 'G',
#   'row': 28,
#   'value': 0.22447388130126916,
#   'formula': '=F28',
#   'precedents': ['H28', 'G88'],
#   'dependencies': ['F28'],
#   'column_name': '2023-12-31',
#   'row_name': None},
#  {'cell_location': 'H28',
#   'column': 'H',
#   'row': 28,
#   'value': 0.22447388130126916,
#   'formula': '=G28',
#   'precedents': ['I28', 'H88'],
#   'dependencies': ['G28'],
#   'column_name': '2024-12-31',
#   'row_name': None},
#  {'cell_location': 'I28',
#   'column': 'I',
#   'row': 28,
#   'value': 0.22447388130126916,
#   'formula': '=H28',
#   'precedents': ['J28', 'I88'],
#   'dependencies': ['H28'],
#   'column_name': '2025-12-31',
#   'row_name': None},
#  {'cell_location': 'J28',
#   'column': 'J',
#   'row': 28,
#   'value': 0.22447388130126916,
#   'formula': '=I28',
#   'precedents': ['J88'],
#   'dependencies': ['I28'],
#   'column_name': '2026-12-31',
#   'row_name': None},
#  {'cell_location': 'B29',
#   'column': 'B',
#   'row': 29,
#   'value': 'Other Liabilities  % Total Expenses:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None},
#  {'cell_location': 'D29',
#   'column': 'D',
#   'row': 29,
#   'value': 0.14557133809825387,
#   'formula': '=-D91/SUM(D58:D60)',
#   'precedents': None,
#   'dependencies': ['D91', 'D58', 'D60'],
#   'column_name': '2020-12-31',
#   'row_name': None},
#  {'cell_location': 'E29',
#   'column': 'E',
#   'row': 29,
#   'value': 0.11717982312479529,
#   'formula': '=-E91/SUM(E58:E60)',
#   'precedents': ['F29'],
#   'dependencies': ['E91', 'E58', 'E60'],
#   'column_name': '2021-12-31',
#   'row_name': None},
#  {'cell_location': 'F29',
#   'column': 'F',
#   'row': 29,
#   'value': 0.13137558061152457,
#   'formula': '=AVERAGE(C29:E29)',
#   'precedents': ['G29', 'F91'],
#   'dependencies': ['C29', 'E29'],
#   'column_name': '2022-12-31',
#   'row_name': None},
#  {'cell_location': 'G29',
#   'column': 'G',
#   'row': 29,
#   'value': 0.13137558061152457,
#   'formula': '=F29',
#   'precedents': ['H29', 'G91'],
#   'dependencies': ['F29'],
#   'column_name': '2023-12-31',
#   'row_name': None},
#  {'cell_location': 'H29',
#   'column': 'H',
#   'row': 29,
#   'value': 0.13137558061152457,
#   'formula': '=G29',
#   'precedents': ['I29', 'H91'],
#   'dependencies': ['G29'],
#   'column_name': '2024-12-31',
#   'row_name': None},
#  {'cell_location': 'I29',
#   'column': 'I',
#   'row': 29,
#   'value': 0.13137558061152457,
#   'formula': '=H29',
#   'precedents': ['J29', 'I91'],
#   'dependencies': ['H29'],
#   'column_name': '2025-12-31',
#   'row_name': None},
#  {'cell_location': 'J29',
#   'column': 'J',
#   'row': 29,
#   'value': 0.13137558061152457,
#   'formula': '=I29',
#   'precedents': ['J91'],
#   'dependencies': ['I29'],
#   'column_name': '2026-12-31',
#   'row_name': None},
#  {'cell_location': 'B31',
#   'column': 'B',
#   'row': 31,
#   'value': 'CapEx % Revenue:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None},
#  {'cell_location': 'C31',
#   'column': 'C',
#   'row': 31,
#   'value': 0.011053514255221832,
#   'formula': '=-C112/C56',
#   'precedents': ['F31'],
#   'dependencies': ['C112', 'C56'],
#   'column_name': '2019-12-31',
#   'row_name': None},
#  {'cell_location': 'D31',
#   'column': 'D',
#   'row': 31,
#   'value': 0.014346190028222013,
#   'formula': '=-D112/D56',
#   'precedents': None,
#   'dependencies': ['D112', 'D56'],
#   'column_name': '2020-12-31',
#   'row_name': None},
#  {'cell_location': 'E31',
#   'column': 'E',
#   'row': 31,
#   'value': 0.010910616869492237,
#   'formula': '=-E112/E56',
#   'precedents': ['F31'],
#   'dependencies': ['E112', 'E56'],
#   'column_name': '2021-12-31',
#   'row_name': None},
#  {'cell_location': 'F31',
#   'column': 'F',
#   'row': 31,
#   'value': 0.012103440384312028,
#   'formula': '=AVERAGE(C31:E31)',
#   'precedents': ['G31', 'F112'],
#   'dependencies': ['C31', 'E31'],
#   'column_name': '2022-12-31',
#   'row_name': None},
#  {'cell_location': 'G31',
#   'column': 'G',
#   'row': 31,
#   'value': 0.012103440384312028,
#   'formula': '=F31',
#   'precedents': ['H31', 'G112'],
#   'dependencies': ['F31'],
#   'column_name': '2023-12-31',
#   'row_name': None},
#  {'cell_location': 'H31',
#   'column': 'H',
#   'row': 31,
#   'value': 0.012103440384312028,
#   'formula': '=G31',
#   'precedents': ['I31', 'H112'],
#   'dependencies': ['G31'],
#   'column_name': '2024-12-31',
#   'row_name': None},
#  {'cell_location': 'I31',
#   'column': 'I',
#   'row': 31,
#   'value': 0.012103440384312028,
#   'formula': '=H31',
#   'precedents': ['J31', 'I112'],
#   'dependencies': ['H31'],
#   'column_name': '2025-12-31',
#   'row_name': None},
#  {'cell_location': 'J31',
#   'column': 'J',
#   'row': 31,
#   'value': 0.012103440384312028,
#   'formula': '=I31',
#   'precedents': ['J112'],
#   'dependencies': ['I31'],
#   'column_name': '2026-12-31',
#   'row_name': None},
#  {'cell_location': 'B32',
#   'column': 'B',
#   'row': 32,
#   'value': 'D&A % Revenue:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None},
#  {'cell_location': 'C32',
#   'column': 'C',
#   'row': 32,
#   'value': 0.013721603903033999,
#   'formula': '=C106/C56',
#   'precedents': ['F32'],
#   'dependencies': ['C106', 'C56'],
#   'column_name': '2019-12-31',
#   'row_name': None},
#  {'cell_location': 'D32',
#   'column': 'D',
#   'row': 32,
#   'value': 0.014973345876450299,
#   'formula': '=D106/D56',
#   'precedents': None,
#   'dependencies': ['D106', 'D56'],
#   'column_name': '2020-12-31',
#   'row_name': None},
#  {'cell_location': 'E32',
#   'column': 'E',
#   'row': 32,
#   'value': 0.01419778990068541,
#   'formula': '=E106/E56',
#   'precedents': ['F32'],
#   'dependencies': ['E106', 'E56'],
#   'column_name': '2021-12-31',
#   'row_name': None},
#  {'cell_location': 'F32',
#   'column': 'F',
#   'row': 32,
#   'value': 0.014297579893389903,
#   'formula': '=AVERAGE(C32:E32)',
#   'precedents': ['G32', 'F106'],
#   'dependencies': ['C32', 'E32'],
#   'column_name': '2022-12-31',
#   'row_name': None},
#  {'cell_location': 'G32',
#   'column': 'G',
#   'row': 32,
#   'value': 0.014297579893389903,
#   'formula': '=F32',
#   'precedents': ['H32', 'G106'],
#   'dependencies': ['F32'],
#   'column_name': '2023-12-31',
#   'row_name': None},
#  {'cell_location': 'H32',
#   'column': 'H',
#   'row': 32,
#   'value': 0.014297579893389903,
#   'formula': '=G32',
#   'precedents': ['I32', 'H106'],
#   'dependencies': ['G32'],
#   'column_name': '2024-12-31',
#   'row_name': None},
#  {'cell_location': 'I32',
#   'column': 'I',
#   'row': 32,
#   'value': 0.014297579893389903,
#   'formula': '=H32',
#   'precedents': ['J32', 'I106'],
#   'dependencies': ['H32'],
#   'column_name': '2025-12-31',
#   'row_name': None},
#  {'cell_location': 'J32',
#   'column': 'J',
#   'row': 32,
#   'value': 0.014297579893389903,
#   'formula': '=I32',
#   'precedents': ['J106'],
#   'dependencies': ['I32'],
#   'column_name': '2026-12-31',
#   'row_name': None},
#  {'cell_location': 'B33',
#   'column': 'B',
#   'row': 33,
#   'value': 'Pensions/Other Items % Revenue:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None},
#  {'cell_location': 'C33',
#   'column': 'C',
#   'row': 33,
#   'value': 0.0041164811709102,
#   'formula': '=C107/C56',
#   'precedents': ['F33'],
#   'dependencies': ['C107', 'C56'],
#   'column_name': '2019-12-31',
#   'row_name': None},
#  {'cell_location': 'D33',
#   'column': 'D',
#   'row': 33,
#   'value': 0.012229539040451553,
#   'formula': '=D107/D56',
#   'precedents': None,
#   'dependencies': ['D107', 'D56'],
#   'column_name': '2020-12-31',
#   'row_name': None},
#  {'cell_location': 'E33',
#   'column': 'E',
#   'row': 33,
#   'value': -0.0023080151070079733,
#   'formula': '=E107/E56',
#   'precedents': ['F33'],
#   'dependencies': ['E107', 'E56'],
#   'column_name': '2021-12-31',
#   'row_name': None},
#  {'cell_location': 'F33',
#   'column': 'F',
#   'row': 33,
#   'value': 0.004679335034784593,
#   'formula': '=AVERAGE(C33:E33)',
#   'precedents': ['G33', 'F107'],
#   'dependencies': ['C33', 'E33'],
#   'column_name': '2022-12-31',
#   'row_name': None},
#  {'cell_location': 'G33',
#   'column': 'G',
#   'row': 33,
#   'value': 0.004679335034784593,
#   'formula': '=F33',
#   'precedents': ['H33', 'G107'],
#   'dependencies': ['F33'],
#   'column_name': '2023-12-31',
#   'row_name': None},
#  {'cell_location': 'H33',
#   'column': 'H',
#   'row': 33,
#   'value': 0.004679335034784593,
#   'formula': '=G33',
#   'precedents': ['I33', 'H107'],
#   'dependencies': ['G33'],
#   'column_name': '2024-12-31',
#   'row_name': None},
#  {'cell_location': 'I33',
#   'column': 'I',
#   'row': 33,
#   'value': 0.004679335034784593,
#   'formula': '=H33',
#   'precedents': ['J33', 'I107'],
#   'dependencies': ['H33'],
#   'column_name': '2025-12-31',
#   'row_name': None},
#  {'cell_location': 'J33',
#   'column': 'J',
#   'row': 33,
#   'value': 0.004679335034784593,
#   'formula': '=I33',
#   'precedents': ['J107'],
#   'dependencies': ['I33'],
#   'column_name': '2026-12-31',
#   'row_name': None},
#  {'cell_location': 'B35',
#   'column': 'B',
#   'row': 35,
#   'value': 'Acquisitions & Other:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None},
#  {'cell_location': 'C35',
#   'column': 'C',
#   'row': 35,
#   'value': -58,
#   'formula': '=C113',
#   'precedents': None,
#   'dependencies': ['C113'],
#   'column_name': '2019-12-31',
#   'row_name': None},
#  {'cell_location': 'D35',
#   'column': 'D',
#   'row': 35,
#   'value': -170,
#   'formula': '=D113',
#   'precedents': None,
#   'dependencies': ['D113'],
#   'column_name': '2020-12-31',
#   'row_name': None},
#  {'cell_location': 'E35',
#   'column': 'E',
#   'row': 35,
#   'value': 67,
#   'formula': '=E113',
#   'precedents': None,
#   'dependencies': ['E113'],
#   'column_name': '2021-12-31',
#   'row_name': None},
#  {'cell_location': 'F35',
#   'column': 'F',
#   'row': 35,
#   'value': -75,
#   'formula': None,
#   'precedents': ['G35', 'F113'],
#   'dependencies': None,
#   'column_name': '2022-12-31',
#   'row_name': None},
#  {'cell_location': 'G35',
#   'column': 'G',
#   'row': 35,
#   'value': -75,
#   'formula': '=F35',
#   'precedents': ['H35', 'G113'],
#   'dependencies': ['F35'],
#   'column_name': '2023-12-31',
#   'row_name': None},
#  {'cell_location': 'H35',
#   'column': 'H',
#   'row': 35,
#   'value': -75,
#   'formula': '=G35',
#   'precedents': ['I35', 'H113'],
#   'dependencies': ['G35'],
#   'column_name': '2024-12-31',
#   'row_name': None},
#  {'cell_location': 'I35',
#   'column': 'I',
#   'row': 35,
#   'value': -75,
#   'formula': '=H35',
#   'precedents': ['J35', 'I113'],
#   'dependencies': ['H35'],
#   'column_name': '2025-12-31',
#   'row_name': None},
#  {'cell_location': 'J35',
#   'column': 'J',
#   'row': 35,
#   'value': -75,
#   'formula': '=I35',
#   'precedents': ['J113'],
#   'dependencies': ['I35'],
#   'column_name': '2026-12-31',
#   'row_name': None},
#  {'cell_location': 'B37',
#   'column': 'B',
#   'row': 37,
#   'value': 'Minimum Cash:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None},
#  {'cell_location': 'E37',
#   'column': 'E',
#   'row': 37,
#   'value': 3000,
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': '2021-12-31',
#   'row_name': None},
#  {'cell_location': 'B38',
#   'column': 'B',
#   'row': 38,
#   'value': 'Excess Cash Flow:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None},
#  {'cell_location': 'F38',
#   'column': 'F',
#   'row': 38,
#   'value': 1654.6223864893436,
#   'formula': '=E77+F109+F114+F118+F120+F124-$E$37',
#   'precedents': ['F44', 'F44', 'F44', 'F46'],
#   'dependencies': ['E77', 'F109', 'F114', 'F118', 'F120', 'F124'],
#   'column_name': '2022-12-31',
#   'row_name': None},
#  {'cell_location': 'G38',
#   'column': 'G',
#   'row': 38,
#   'value': 1022.1419276514534,
#   'formula': '=F77+G109+G114+G118+G120+G124-$E$37',
#   'precedents': ['G44', 'G44', 'G44', 'G46'],
#   'dependencies': ['F77', 'G109', 'G114', 'G118', 'G120', 'G124'],
#   'column_name': '2023-12-31',
#   'row_name': None},
#  {'cell_location': 'H38',
#   'column': 'H',
#   'row': 38,
#   'value': 1045.8087874340235,
#   'formula': '=G77+H109+H114+H118+H120+H124-$E$37',
#   'precedents': ['H44', 'H44', 'H44', 'H46'],
#   'dependencies': ['G77', 'H109', 'H114', 'H118', 'H120', 'H124'],
#   'column_name': '2024-12-31',
#   'row_name': None},
#  {'cell_location': 'I38',
#   'column': 'I',
#   'row': 38,
#   'value': 1085.4837364468235,
#   'formula': '=H77+I109+I114+I118+I120+I124-$E$37',
#   'precedents': ['I44', 'I44', 'I44', 'I46'],
#   'dependencies': ['H77', 'I109', 'I114', 'I118', 'I120', 'I124'],
#   'column_name': '2025-12-31',
#   'row_name': None},
#  {'cell_location': 'J38',
#   'column': 'J',
#   'row': 38,
#   'value': 1124.2962186090426,
#   'formula': '=I77+J109+J114+J118+J120+J124-$E$37',
#   'precedents': ['J44', 'J44', 'J44', 'J46'],
#   'dependencies': ['I77', 'J109', 'J114', 'J118', 'J120', 'J124'],
#   'column_name': '2026-12-31',
#   'row_name': None},
#  {'cell_location': 'B39',
#   'column': 'B',
#   'row': 39,
#   'value': '% Stock Repurchases:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None},
#  {'cell_location': 'E39',
#   'column': 'E',
#   'row': 39,
#   'value': 0.85,
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': '2021-12-31',
#   'row_name': None},
#  {'cell_location': 'B40',
#   'column': 'B',
#   'row': 40,
#   'value': '% Debt Repayment:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None},
#  {'cell_location': 'E40',
#   'column': 'E',
#   'row': 40,
#   'value': 0.15,
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': '2021-12-31',
#   'row_name': None},
#  {'cell_location': 'B42',
#   'column': 'B',
#   'row': 42,
#   'value': 'Interest Expense % Debt:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None},
#  {'cell_location': 'D42',
#   'column': 'D',
#   'row': 42,
#   'value': 0.020459500251551233,
#   'formula': '=-D65/D89',
#   'precedents': None,
#   'dependencies': ['D65', 'D89'],
#   'column_name': '2020-12-31',
# ...
#   'formula': '=G44',
#   'precedents': ['G89', 'G121', 'G122'],
#   'dependencies': ['G44'],
#   'column_name': '2023-12-31',
#   'row_name': '(+/-) Change in Debt:'},
#  {'cell_location': 'H117',
#   'column': 'H',
#   'row': 117,
#   'value': -156.87131811510352,
#   'formula': '=H44',
#   'precedents': ['H89', 'H121', 'H122'],
#   'dependencies': ['H44'],
#   'column_name': '2024-12-31',
#   'row_name': '(+/-) Change in Debt:'},
#  {'cell_location': 'I117',
#   'column': 'I',
#   'row': 117,
#   'value': -162.82256046702352,
#   'formula': '=I44',
#   'precedents': ['I89', 'I121', 'I122'],
#   'dependencies': ['I44'],
#   'column_name': '2025-12-31',
#   'row_name': '(+/-) Change in Debt:'},
#  {'cell_location': 'J117',
#   'column': 'J',
#   'row': 117,
#   'value': -168.6444327913564,
#   'formula': '=J44',
#   'precedents': ['J89', 'J121', 'J122'],
#   'dependencies': ['J44'],
#   'column_name': '2026-12-31',
#   'row_name': '(+/-) Change in Debt:'},
#  {'cell_location': 'B118',
#   'column': 'B',
#   'row': 118,
#   'value': '(-) Common Dividends:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': '(-) Dividends to NCI:'},
#  {'cell_location': 'C118',
#   'column': 'C',
#   'row': 118,
#   'value': 0,
#   'formula': None,
#   'precedents': ['C45'],
#   'dependencies': None,
#   'column_name': '2019-12-31',
#   'row_name': '(-) Dividends to NCI:'},
#  {'cell_location': 'D118',
#   'column': 'D',
#   'row': 118,
#   'value': -260,
#   'formula': None,
#   'precedents': ['D45'],
#   'dependencies': None,
#   'column_name': '2020-12-31',
#   'row_name': '(-) Dividends to NCI:'},
#  {'cell_location': 'E118',
#   'column': 'E',
#   'row': 118,
#   'value': -393,
#   'formula': None,
#   'precedents': ['E45'],
#   'dependencies': None,
#   'column_name': '2021-12-31',
#   'row_name': '(-) Dividends to NCI:'},
#  {'cell_location': 'F118',
#   'column': 'F',
#   'row': 118,
#   'value': -411.7234186302995,
#   'formula': '=-F72*F45',
#   'precedents': ['F38', 'F94'],
#   'dependencies': ['F72', 'F45'],
#   'column_name': '2022-12-31',
#   'row_name': '(-) Dividends to NCI:'},
#  {'cell_location': 'G118',
#   'column': 'G',
#   'row': 118,
#   'value': -466.0704830232179,
#   'formula': '=-G72*G45',
#   'precedents': ['G38', 'G94'],
#   'dependencies': ['G72', 'G45'],
#   'column_name': '2023-12-31',
#   'row_name': '(-) Dividends to NCI:'},
#  {'cell_location': 'H118',
#   'column': 'H',
#   'row': 118,
#   'value': -533.7492450831841,
#   'formula': '=-H72*H45',
#   'precedents': ['H38', 'H94'],
#   'dependencies': ['H72', 'H45'],
#   'column_name': '2024-12-31',
#   'row_name': '(-) Dividends to NCI:'},
#  {'cell_location': 'I118',
#   'column': 'I',
#   'row': 118,
#   'value': -561.4627156033544,
#   'formula': '=-I72*I45',
#   'precedents': ['I38', 'I94'],
#   'dependencies': ['I72', 'I45'],
#   'column_name': '2025-12-31',
#   'row_name': '(-) Dividends to NCI:'},
#  {'cell_location': 'J118',
#   'column': 'J',
#   'row': 118,
#   'value': -599.0362973788734,
#   'formula': '=-J72*J45',
#   'precedents': ['J38', 'J94'],
#   'dependencies': ['J72', 'J45'],
#   'column_name': '2026-12-31',
#   'row_name': '(-) Dividends to NCI:'},
#  {'cell_location': 'B119',
#   'column': 'B',
#   'row': 119,
#   'value': '(-) Stock Repurchases:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': '(-) Stock Repurchases:'},
#  {'cell_location': 'C119',
#   'column': 'C',
#   'row': 119,
#   'value': 0,
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': '2019-12-31',
#   'row_name': '(-) Stock Repurchases:'},
#  {'cell_location': 'D119',
#   'column': 'D',
#   'row': 119,
#   'value': 0,
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': '2020-12-31',
#   'row_name': '(-) Stock Repurchases:'},
#  {'cell_location': 'E119',
#   'column': 'E',
#   'row': 119,
#   'value': -725,
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': '2021-12-31',
#   'row_name': '(-) Stock Repurchases:'},
#  {'cell_location': 'F119',
#   'column': 'F',
#   'row': 119,
#   'value': -1406.429028515942,
#   'formula': '=F46',
#   'precedents': ['F94'],
#   'dependencies': ['F46'],
#   'column_name': '2022-12-31',
#   'row_name': '(-) Stock Repurchases:'},
#  {'cell_location': 'G119',
#   'column': 'G',
#   'row': 119,
#   'value': -868.8206385037354,
#   'formula': '=G46',
#   'precedents': ['G94'],
#   'dependencies': ['G46'],
#   'column_name': '2023-12-31',
#   'row_name': '(-) Stock Repurchases:'},
#  {'cell_location': 'H119',
#   'column': 'H',
#   'row': 119,
#   'value': -888.93746931892,
#   'formula': '=H46',
#   'precedents': ['H94'],
#   'dependencies': ['H46'],
#   'column_name': '2024-12-31',
#   'row_name': '(-) Stock Repurchases:'},
#  {'cell_location': 'I119',
#   'column': 'I',
#   'row': 119,
#   'value': -922.6611759798,
#   'formula': '=I46',
#   'precedents': ['I94'],
#   'dependencies': ['I46'],
#   'column_name': '2025-12-31',
#   'row_name': '(-) Stock Repurchases:'},
#  {'cell_location': 'J119',
#   'column': 'J',
#   'row': 119,
#   'value': -955.6517858176862,
#   'formula': '=J46',
#   'precedents': ['J94'],
#   'dependencies': ['J46'],
#   'column_name': '2026-12-31',
#   'row_name': '(-) Stock Repurchases:'},
#  {'cell_location': 'B120',
#   'column': 'B',
#   'row': 120,
#   'value': '(-) Dividends to NCI:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': '(-) Dividends to NCI:'},
#  {'cell_location': 'C120',
#   'column': 'C',
#   'row': 120,
#   'value': -163,
#   'formula': None,
#   'precedents': ['C47'],
#   'dependencies': None,
#   'column_name': '2019-12-31',
#   'row_name': '(-) Dividends to NCI:'},
#  {'cell_location': 'D120',
#   'column': 'D',
#   'row': 120,
#   'value': -149,
#   'formula': None,
#   'precedents': ['D47'],
#   'dependencies': None,
#   'column_name': '2020-12-31',
#   'row_name': '(-) Dividends to NCI:'},
#  {'cell_location': 'E120',
#   'column': 'E',
#   'row': 120,
#   'value': -155,
#   'formula': None,
#   'precedents': ['E47'],
#   'dependencies': None,
#   'column_name': '2021-12-31',
#   'row_name': '(-) Dividends to NCI:'},
#  {'cell_location': 'F120',
#   'column': 'F',
#   'row': 120,
#   'value': -170.45861326550573,
#   'formula': '=-F105*F47',
#   'precedents': ['F38', 'F95'],
#   'dependencies': ['F105', 'F47'],
#   'column_name': '2022-12-31',
#   'row_name': '(-) Dividends to NCI:'},
#  {'cell_location': 'G120',
#   'column': 'G',
#   'row': 120,
#   'value': -180.0950419226988,
#   'formula': '=-G105*G47',
#   'precedents': ['G38', 'G95'],
#   'dependencies': ['G105', 'G47'],
#   'column_name': '2023-12-31',
#   'row_name': '(-) Dividends to NCI:'},
#  {'cell_location': 'H120',
#   'column': 'H',
#   'row': 120,
#   'value': -193.35646948303736,
#   'formula': '=-H105*H47',
#   'precedents': ['H38', 'H95'],
#   'dependencies': ['H105', 'H47'],
#   'column_name': '2024-12-31',
#   'row_name': '(-) Dividends to NCI:'},
#  {'cell_location': 'I120',
#   'column': 'I',
#   'row': 120,
#   'value': -203.39597561117677,
#   'formula': '=-I105*I47',
#   'precedents': ['I38', 'I95'],
#   'dependencies': ['I105', 'I47'],
#   'column_name': '2025-12-31',
#   'row_name': '(-) Dividends to NCI:'},
#  {'cell_location': 'J120',
#   'column': 'J',
#   'row': 120,
#   'value': -217.0074142874306,
#   'formula': '=-J105*J47',
#   'precedents': ['J38', 'J95'],
#   'dependencies': ['J105', 'J47'],
#   'column_name': '2026-12-31',
#   'row_name': '(-) Dividends to NCI:'},
#  {'cell_location': 'B121',
#   'column': 'B',
#   'row': 121,
#   'value': '(+/-) Other Items:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': '(+/-) Other Items:'},
#  {'cell_location': 'C121',
#   'column': 'C',
#   'row': 121,
#   'value': -976,
#   'formula': None,
#   'precedents': ['C122'],
#   'dependencies': None,
#   'column_name': '2019-12-31',
#   'row_name': '(+/-) Other Items:'},
#  {'cell_location': 'D121',
#   'column': 'D',
#   'row': 121,
#   'value': -6382,
#   'formula': None,
#   'precedents': ['D122'],
#   'dependencies': None,
#   'column_name': '2020-12-31',
#   'row_name': '(+/-) Other Items:'},
#  {'cell_location': 'E121',
#   'column': 'E',
#   'row': 121,
#   'value': -44,
#   'formula': None,
#   'precedents': ['E49', 'E122'],
#   'dependencies': None,
#   'column_name': '2021-12-31',
#   'row_name': '(+/-) Other Items:'},
#  {'cell_location': 'F121',
#   'column': 'F',
#   'row': 121,
#   'value': 0,
#   'formula': '=MAX(F117,0)*F49',
#   'precedents': ['F94', 'F122'],
#   'dependencies': ['F117', 'F49'],
#   'column_name': '2022-12-31',
#   'row_name': '(+/-) Other Items:'},
#  {'cell_location': 'G121',
#   'column': 'G',
#   'row': 121,
#   'value': 0,
#   'formula': '=MAX(G117,0)*G49',
#   'precedents': ['G94', 'G122'],
#   'dependencies': ['G117', 'G49'],
#   'column_name': '2023-12-31',
#   'row_name': '(+/-) Other Items:'},
#  {'cell_location': 'H121',
#   'column': 'H',
#   'row': 121,
#   'value': 0,
#   'formula': '=MAX(H117,0)*H49',
#   'precedents': ['H94', 'H122'],
#   'dependencies': ['H117', 'H49'],
#   'column_name': '2024-12-31',
#   'row_name': '(+/-) Other Items:'},
#  {'cell_location': 'I121',
#   'column': 'I',
#   'row': 121,
#   'value': 0,
#   'formula': '=MAX(I117,0)*I49',
#   'precedents': ['I94', 'I122'],
#   'dependencies': ['I117', 'I49'],
#   'column_name': '2025-12-31',
#   'row_name': '(+/-) Other Items:'},
#  {'cell_location': 'J121',
#   'column': 'J',
#   'row': 121,
#   'value': 0,
#   'formula': '=MAX(J117,0)*J49',
#   'precedents': ['J94', 'J122'],
#   'dependencies': ['J117', 'J49'],
#   'column_name': '2026-12-31',
#   'row_name': '(+/-) Other Items:'},
#  {'cell_location': 'B122',
#   'column': 'B',
#   'row': 122,
#   'value': 'Cash Flow from Financing:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': 'Cash Flow from Financing:'},
#  {'cell_location': 'C122',
#   'column': 'C',
#   'row': 122,
#   'value': -1133,
#   'formula': '=SUM(C117:C121)',
#   'precedents': ['C126'],
#   'dependencies': ['C117', 'C121'],
#   'column_name': '2019-12-31',
#   'row_name': 'Cash Flow from Financing:'},
#  {'cell_location': 'D122',
#   'column': 'D',
#   'row': 122,
#   'value': -844,
#   'formula': '=SUM(D117:D121)',
#   'precedents': ['D126'],
#   'dependencies': ['D117', 'D121'],
#   'column_name': '2020-12-31',
#   'row_name': 'Cash Flow from Financing:'},
#  {'cell_location': 'E122',
#   'column': 'E',
#   'row': 122,
#   'value': 58,
#   'formula': '=SUM(E117:E121)',
#   'precedents': ['E126'],
#   'dependencies': ['E117', 'E121'],
#   'column_name': '2021-12-31',
#   'row_name': 'Cash Flow from Financing:'},
#  {'cell_location': 'F122',
#   'column': 'F',
#   'row': 122,
#   'value': -2236.804418385149,
#   'formula': '=SUM(F117:F121)',
#   'precedents': ['F126'],
#   'dependencies': ['F117', 'F121'],
#   'column_name': '2022-12-31',
#   'row_name': 'Cash Flow from Financing:'},
#  {'cell_location': 'G122',
#   'column': 'G',
#   'row': 122,
#   'value': -1668.30745259737,
#   'formula': '=SUM(G117:G121)',
#   'precedents': ['G126'],
#   'dependencies': ['G117', 'G121'],
#   'column_name': '2023-12-31',
#   'row_name': 'Cash Flow from Financing:'},
#  {'cell_location': 'H122',
#   'column': 'H',
#   'row': 122,
#   'value': -1772.9145020002447,
#   'formula': '=SUM(H117:H121)',
#   'precedents': ['H126'],
#   'dependencies': ['H117', 'H121'],
#   'column_name': '2024-12-31',
#   'row_name': 'Cash Flow from Financing:'},
#  {'cell_location': 'I122',
#   'column': 'I',
#   'row': 122,
#   'value': -1850.3424276613546,
#   'formula': '=SUM(I117:I121)',
#   'precedents': ['I126'],
#   'dependencies': ['I117', 'I121'],
#   'column_name': '2025-12-31',
#   'row_name': 'Cash Flow from Financing:'},
#  {'cell_location': 'J122',
#   'column': 'J',
#   'row': 122,
#   'value': -1940.3399302753464,
#   'formula': '=SUM(J117:J121)',
#   'precedents': ['J126'],
#   'dependencies': ['J117', 'J121'],
#   'column_name': '2026-12-31',
#   'row_name': 'Cash Flow from Financing:'},
#  {'cell_location': 'B124',
#   'column': 'B',
#   'row': 124,
#   'value': 'FX Rate Effects:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': 'FX Rate Effects:'},
#  {'cell_location': 'C124',
#   'column': 'C',
#   'row': 124,
#   'value': -20,
#   'formula': None,
#   'precedents': ['C50', 'C126'],
#   'dependencies': None,
#   'column_name': '2019-12-31',
#   'row_name': 'FX Rate Effects:'},
#  {'cell_location': 'D124',
#   'column': 'D',
#   'row': 124,
#   'value': 59,
#   'formula': None,
#   'precedents': ['D50', 'D126'],
#   'dependencies': None,
#   'column_name': '2020-12-31',
#   'row_name': 'FX Rate Effects:'},
#  {'cell_location': 'E124',
#   'column': 'E',
#   'row': 124,
#   'value': -43,
#   'formula': None,
#   'precedents': ['E50', 'E126'],
#   'dependencies': None,
#   'column_name': '2021-12-31',
#   'row_name': 'FX Rate Effects:'},
#  {'cell_location': 'F124',
#   'column': 'F',
#   'row': 124,
#   'value': 0.4717768322516428,
#   'formula': '=F56*F50',
#   'precedents': ['F38', 'F94', 'F126'],
#   'dependencies': ['F56', 'F50'],
#   'column_name': '2022-12-31',
#   'row_name': 'FX Rate Effects:'},
#  {'cell_location': 'G124',
#   'column': 'G',
#   'row': 124,
#   'value': 0.5020182129943402,
#   'formula': '=G56*G50',
#   'precedents': ['G38', 'G94', 'G126'],
#   'dependencies': ['G56', 'G50'],
#   'column_name': '2023-12-31',
#   'row_name': 'FX Rate Effects:'},
#  {'cell_location': 'H124',
#   'column': 'H',
#   'row': 124,
#   'value': 0.531920284122122,
#   'formula': '=H56*H50',
#   'precedents': ['H38', 'H94', 'H126'],
#   'dependencies': ['H56', 'H50'],
#   'column_name': '2024-12-31',
#   'row_name': 'FX Rate Effects:'},
#  {'cell_location': 'I124',
#   'column': 'I',
#   'row': 124,
#   'value': 0.5607438594977763,
#   'formula': '=I56*I50',
#   'precedents': ['I38', 'I94', 'I126'],
#   'dependencies': ['I56', 'I50'],
#   'column_name': '2025-12-31',
#   'row_name': 'FX Rate Effects:'},
#  {'cell_location': 'J124',
#   'column': 'J',
#   'row': 124,
#   'value': 0.5873274275509285,
#   'formula': '=J56*J50',
#   'precedents': ['J38', 'J94', 'J126'],
#   'dependencies': ['J56', 'J50'],
#   'column_name': '2026-12-31',
#   'row_name': 'FX Rate Effects:'},
#  {'cell_location': 'B126',
#   'column': 'B',
#   'row': 126,
#   'value': 'Net Change in Cash:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': 'Net Change in Cash:'},
#  {'cell_location': 'C126',
#   'column': 'C',
#   'row': 126,
#   'value': 113,
#   'formula': '=C109+C114+C122+C124',
#   'precedents': None,
#   'dependencies': ['C109', 'C114', 'C122', 'C124'],
#   'column_name': '2019-12-31',
#   'row_name': 'Net Change in Cash:'},
#  {'cell_location': 'D126',
#   'column': 'D',
#   'row': 126,
#   'value': 342,
#   'formula': '=D109+D114+D122+D124',
#   'precedents': None,
#   'dependencies': ['D109', 'D114', 'D122', 'D124'],
#   'column_name': '2020-12-31',
#   'row_name': 'Net Change in Cash:'},
#  {'cell_location': 'E126',
#   'column': 'E',
#   'row': 126,
#   'value': 1676,
#   'formula': '=E109+E114+E122+E124',
#   'precedents': None,
#   'dependencies': ['E109', 'E114', 'E122', 'E124'],
#   'column_name': '2021-12-31',
#   'row_name': 'Net Change in Cash:'},
#  {'cell_location': 'F126',
#   'column': 'F',
#   'row': 126,
#   'value': -475.0000000000002,
#   'formula': '=F109+F114+F122+F124',
#   'precedents': ['F77'],
#   'dependencies': ['F109', 'F114', 'F122', 'F124'],
#   'column_name': '2022-12-31',
#   'row_name': 'Net Change in Cash:'},
#  {'cell_location': 'G126',
#   'column': 'G',
#   'row': 126,
#   'value': -1.312283615106935e-13,
#   'formula': '=G109+G114+G122+G124',
#   'precedents': ['G77'],
#   'dependencies': ['G109', 'G114', 'G122', 'G124'],
#   'column_name': '2023-12-31',
#   'row_name': 'Net Change in Cash:'},
#  {'cell_location': 'H126',
#   'column': 'H',
#   'row': 126,
#   'value': 1.6986412276764895e-13,
#   'formula': '=H109+H114+H122+H124',
#   'precedents': ['H77'],
#   'dependencies': ['H109', 'H114', 'H122', 'H124'],
#   'column_name': '2024-12-31',
#   'row_name': 'Net Change in Cash:'},
#  {'cell_location': 'I126',
#   'column': 'I',
#   'row': 126,
#   'value': -1.0944578576754793e-12,
#   'formula': '=I109+I114+I122+I124',
#   'precedents': ['I77'],
#   'dependencies': ['I109', 'I114', 'I122', 'I124'],
#   'column_name': '2025-12-31',
#   'row_name': 'Net Change in Cash:'},
#  {'cell_location': 'J126',
#   'column': 'J',
#   'row': 126,
#   'value': 1.8299806114896455e-12,
#   'formula': '=J109+J114+J122+J124',
#   'precedents': ['J77'],
#   'dependencies': ['J109', 'J114', 'J122', 'J124'],
#   'column_name': '2026-12-31',
#   'row_name': 'Net Change in Cash:'}]

# %%
# Build a lookup dictionary mapping each cell location to its associated row_name (if defined)
ref_to_row_name = {}
for cell in cells_info:
    # Only add mapping if a row_name exists for the cell
    if cell.get('row_name') is not None:
        ref_to_row_name[cell['cell_location']] = cell['row_name']

# Process each cell that contains a formula starting with '='
for cell in cells_info:
    formula = cell.get('formula')
    if formula and formula.startswith('='):
        updated_formula = formula
        # Collect all referenced cell locations from both "precedents" and "dependencies"
        refs = set()
        if cell.get('precedents'):
            refs.update(cell['precedents'])
        if cell.get('dependencies'):
            refs.update(cell['dependencies'])
        
        # Replace each cell reference with the actual row_name if available
        for ref in refs:
            if ref in ref_to_row_name:
                # Replace all occurrences of the cell reference (as a substring)
                updated_formula = updated_formula.replace(ref, str(ref_to_row_name[ref]))
        
        # Save the new formula into the cell's dictionary under a new key
        cell['formula_with_row_names'] = updated_formula

for cell in cells_info:
    # Generate precedents_names by converting each precedent cell reference into its row_name if available
    refs = cell.get('precedents')
    if refs:
        precedents_names = []
        for ref in refs:
            # Use the row name if available, otherwise keep the original reference
            precedents_names.append(ref_to_row_name.get(ref, ref))
        cell['precedents_names'] = precedents_names
    else:
        cell['precedents_names'] = []

    # Generate dependent_names by converting each dependency cell reference into its row_name if available
    deps = cell.get('dependencies')
    if deps:
        dependent_names = []
        for ref in deps:
            # Use the row name if available, otherwise keep the original reference
            dependent_names.append(ref_to_row_name.get(ref, ref))
        cell['dependent_names'] = dependent_names
    else:
        cell['dependent_names'] = []

# %%
cells_info
# Out:
# [{'cell_location': 'B2',
#   'column': 'B',
#   'row': 2,
#   'value': 'Drivers:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None,
#   'precedents_names': [],
#   'dependent_names': []},
#  {'cell_location': 'C2',
#   'column': 'C',
#   'row': 2,
#   'value': datetime.datetime(2019, 12, 31, 0, 0),
#   'formula': None,
#   'precedents': ['D2'],
#   'dependencies': None,
#   'column_name': '2019-12-31',
#   'row_name': None,
#   'precedents_names': ['D2'],
#   'dependent_names': []},
#  {'cell_location': 'D2',
#   'column': 'D',
#   'row': 2,
#   'value': datetime.datetime(2020, 12, 31, 0, 0),
#   'formula': '=EOMONTH(C2,12)',
#   'precedents': ['E2'],
#   'dependencies': ['C2'],
#   'column_name': '2020-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=EOMONTH(C2,12)',
#   'precedents_names': ['E2'],
#   'dependent_names': ['C2']},
#  {'cell_location': 'E2',
#   'column': 'E',
#   'row': 2,
#   'value': datetime.datetime(2021, 12, 31, 0, 0),
#   'formula': '=EOMONTH(D2,12)',
#   'precedents': ['F2'],
#   'dependencies': ['D2'],
#   'column_name': '2021-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=EOMONTH(D2,12)',
#   'precedents_names': ['F2'],
#   'dependent_names': ['D2']},
#  {'cell_location': 'F2',
#   'column': 'F',
#   'row': 2,
#   'value': datetime.datetime(2022, 12, 31, 0, 0),
#   'formula': '=EOMONTH(E2,12)',
#   'precedents': ['G2'],
#   'dependencies': ['E2'],
#   'column_name': '2022-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=EOMONTH(E2,12)',
#   'precedents_names': ['G2'],
#   'dependent_names': ['E2']},
#  {'cell_location': 'G2',
#   'column': 'G',
#   'row': 2,
#   'value': datetime.datetime(2023, 12, 31, 0, 0),
#   'formula': '=EOMONTH(F2,12)',
#   'precedents': ['H2'],
#   'dependencies': ['F2'],
#   'column_name': '2023-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=EOMONTH(F2,12)',
#   'precedents_names': ['H2'],
#   'dependent_names': ['F2']},
#  {'cell_location': 'H2',
#   'column': 'H',
#   'row': 2,
#   'value': datetime.datetime(2024, 12, 31, 0, 0),
#   'formula': '=EOMONTH(G2,12)',
#   'precedents': ['I2'],
#   'dependencies': ['G2'],
#   'column_name': '2024-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=EOMONTH(G2,12)',
#   'precedents_names': ['I2'],
#   'dependent_names': ['G2']},
#  {'cell_location': 'I2',
#   'column': 'I',
#   'row': 2,
#   'value': datetime.datetime(2025, 12, 31, 0, 0),
#   'formula': '=EOMONTH(H2,12)',
#   'precedents': ['J2'],
#   'dependencies': ['H2'],
#   'column_name': '2025-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=EOMONTH(H2,12)',
#   'precedents_names': ['J2'],
#   'dependent_names': ['H2']},
#  {'cell_location': 'J2',
#   'column': 'J',
#   'row': 2,
#   'value': datetime.datetime(2026, 12, 31, 0, 0),
#   'formula': '=EOMONTH(I2,12)',
#   'precedents': None,
#   'dependencies': ['I2'],
#   'column_name': '2026-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=EOMONTH(I2,12)',
#   'precedents_names': [],
#   'dependent_names': ['I2']},
#  {'cell_location': 'B4',
#   'column': 'B',
#   'row': 4,
#   'value': 'New Equipment Market Size:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None,
#   'precedents_names': [],
#   'dependent_names': []},
#  {'cell_location': 'C4',
#   'column': 'C',
#   'row': 4,
#   'value': 35300,
#   'formula': '=C54/C7',
#   'precedents': ['D5'],
#   'dependencies': ['C54', 'C7'],
#   'column_name': '2019-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=Products:/C7',
#   'precedents_names': ['D5'],
#   'dependent_names': ['Products:', 'C7']},
#  {'cell_location': 'D4',
#   'column': 'D',
#   'row': 4,
#   'value': 31594.11764705882,
#   'formula': '=D54/D7',
#   'precedents': ['D5', 'E5'],
#   'dependencies': ['D54', 'D7'],
#   'column_name': '2020-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=Products:/D7',
#   'precedents_names': ['D5', 'E5'],
#   'dependent_names': ['Products:', 'D7']},
#  {'cell_location': 'E4',
#   'column': 'E',
#   'row': 4,
#   'value': 35711.11111111111,
#   'formula': '=E54/E7',
#   'precedents': ['F4', 'E5'],
#   'dependencies': ['E54', 'E7'],
#   'column_name': '2021-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=Products:/E7',
#   'precedents_names': ['F4', 'E5'],
#   'dependent_names': ['Products:', 'E7']},
#  {'cell_location': 'F4',
#   'column': 'F',
#   'row': 4,
#   'value': 37496.666666666664,
#   'formula': '=E4*(1+F5)',
#   'precedents': ['G4', 'F54'],
#   'dependencies': ['E4', 'F5'],
#   'column_name': '2022-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=E4*(1+F5)',
#   'precedents_names': ['G4', 'Products:'],
#   'dependent_names': ['E4', 'F5']},
#  {'cell_location': 'G4',
#   'column': 'G',
#   'row': 4,
#   'value': 39371.5,
#   'formula': '=F4*(1+G5)',
#   'precedents': ['H4', 'G54'],
#   'dependencies': ['F4', 'G5'],
#   'column_name': '2023-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=F4*(1+G5)',
#   'precedents_names': ['H4', 'Products:'],
#   'dependent_names': ['F4', 'G5']},
#  {'cell_location': 'H4',
#   'column': 'H',
#   'row': 4,
#   'value': 40946.36,
#   'formula': '=G4*(1+H5)',
#   'precedents': ['I4', 'H54'],
#   'dependencies': ['G4', 'H5'],
#   'column_name': '2024-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=G4*(1+H5)',
#   'precedents_names': ['I4', 'Products:'],
#   'dependent_names': ['G4', 'H5']},
#  {'cell_location': 'I4',
#   'column': 'I',
#   'row': 4,
#   'value': 42584.214400000004,
#   'formula': '=H4*(1+I5)',
#   'precedents': ['J4', 'I54'],
#   'dependencies': ['H4', 'I5'],
#   'column_name': '2025-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=H4*(1+I5)',
#   'precedents_names': ['J4', 'Products:'],
#   'dependent_names': ['H4', 'I5']},
#  {'cell_location': 'J4',
#   'column': 'J',
#   'row': 4,
#   'value': 43861.740832,
#   'formula': '=I4*(1+J5)',
#   'precedents': ['J54'],
#   'dependencies': ['I4', 'J5'],
#   'column_name': '2026-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=I4*(1+J5)',
#   'precedents_names': ['Products:'],
#   'dependent_names': ['I4', 'J5']},
#  {'cell_location': 'B5',
#   'column': 'B',
#   'row': 5,
#   'value': 'Growth Rate:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None,
#   'precedents_names': [],
#   'dependent_names': []},
#  {'cell_location': 'D5',
#   'column': 'D',
#   'row': 5,
#   'value': -0.10498250291618072,
#   'formula': '=D4/C4-1',
#   'precedents': None,
#   'dependencies': ['D4', 'C4'],
#   'column_name': '2020-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=D4/C4-1',
#   'precedents_names': [],
#   'dependent_names': ['D4', 'C4']},
#  {'cell_location': 'E5',
#   'column': 'E',
#   'row': 5,
#   'value': 0.1303088603405118,
#   'formula': '=E4/D4-1',
#   'precedents': None,
#   'dependencies': ['E4', 'D4'],
#   'column_name': '2021-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=E4/D4-1',
#   'precedents_names': [],
#   'dependent_names': ['E4', 'D4']},
#  {'cell_location': 'F5',
#   'column': 'F',
#   'row': 5,
#   'value': 0.05,
#   'formula': None,
#   'precedents': ['F4'],
#   'dependencies': None,
#   'column_name': '2022-12-31',
#   'row_name': None,
#   'precedents_names': ['F4'],
#   'dependent_names': []},
#  {'cell_location': 'G5',
#   'column': 'G',
#   'row': 5,
#   'value': 0.05,
#   'formula': None,
#   'precedents': ['G4'],
#   'dependencies': None,
#   'column_name': '2023-12-31',
#   'row_name': None,
#   'precedents_names': ['G4'],
#   'dependent_names': []},
#  {'cell_location': 'H5',
#   'column': 'H',
#   'row': 5,
#   'value': 0.04,
#   'formula': None,
#   'precedents': ['H4'],
#   'dependencies': None,
#   'column_name': '2024-12-31',
#   'row_name': None,
#   'precedents_names': ['H4'],
#   'dependent_names': []},
#  {'cell_location': 'I5',
#   'column': 'I',
#   'row': 5,
#   'value': 0.04,
#   'formula': None,
#   'precedents': ['I4'],
#   'dependencies': None,
#   'column_name': '2025-12-31',
#   'row_name': None,
#   'precedents_names': ['I4'],
#   'dependent_names': []},
#  {'cell_location': 'J5',
#   'column': 'J',
#   'row': 5,
#   'value': 0.03,
#   'formula': None,
#   'precedents': ['J4'],
#   'dependencies': None,
#   'column_name': '2026-12-31',
#   'row_name': None,
#   'precedents_names': ['J4'],
#   'dependent_names': []},
#  {'cell_location': 'B7',
#   'column': 'B',
#   'row': 7,
#   'value': 'New Equipment Market Share:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None,
#   'precedents_names': [],
#   'dependent_names': []},
#  {'cell_location': 'C7',
#   'column': 'C',
#   'row': 7,
#   'value': 0.16,
#   'formula': None,
#   'precedents': ['C4'],
#   'dependencies': None,
#   'column_name': '2019-12-31',
#   'row_name': None,
#   'precedents_names': ['C4'],
#   'dependent_names': []},
#  {'cell_location': 'D7',
#   'column': 'D',
#   'row': 7,
#   'value': 0.17,
#   'formula': None,
#   'precedents': ['D4'],
#   'dependencies': None,
#   'column_name': '2020-12-31',
#   'row_name': None,
#   'precedents_names': ['D4'],
#   'dependent_names': []},
#  {'cell_location': 'E7',
#   'column': 'E',
#   'row': 7,
#   'value': 0.18,
#   'formula': None,
#   'precedents': ['E4'],
#   'dependencies': None,
#   'column_name': '2021-12-31',
#   'row_name': None,
#   'precedents_names': ['E4'],
#   'dependent_names': []},
#  {'cell_location': 'F7',
#   'column': 'F',
#   'row': 7,
#   'value': 0.18,
#   'formula': None,
#   'precedents': ['F54'],
#   'dependencies': None,
#   'column_name': '2022-12-31',
#   'row_name': None,
#   'precedents_names': ['Products:'],
#   'dependent_names': []},
#  {'cell_location': 'G7',
#   'column': 'G',
#   'row': 7,
#   'value': 0.182,
#   'formula': None,
#   'precedents': ['G54'],
#   'dependencies': None,
#   'column_name': '2023-12-31',
#   'row_name': None,
#   'precedents_names': ['Products:'],
#   'dependent_names': []},
#  {'cell_location': 'H7',
#   'column': 'H',
#   'row': 7,
#   'value': 0.184,
#   'formula': None,
#   'precedents': ['H54'],
#   'dependencies': None,
#   'column_name': '2024-12-31',
#   'row_name': None,
#   'precedents_names': ['Products:'],
#   'dependent_names': []},
#  {'cell_location': 'I7',
#   'column': 'I',
#   'row': 7,
#   'value': 0.185,
#   'formula': None,
#   'precedents': ['I54'],
#   'dependencies': None,
#   'column_name': '2025-12-31',
#   'row_name': None,
#   'precedents_names': ['Products:'],
#   'dependent_names': []},
#  {'cell_location': 'J7',
#   'column': 'J',
#   'row': 7,
#   'value': 0.185,
#   'formula': None,
#   'precedents': ['J54'],
#   'dependencies': None,
#   'column_name': '2026-12-31',
#   'row_name': None,
#   'precedents_names': ['Products:'],
#   'dependent_names': []},
#  {'cell_location': 'B9',
#   'column': 'B',
#   'row': 9,
#   'value': 'Service Units (Maintenance):',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None,
#   'precedents_names': [],
#   'dependent_names': []},
#  {'cell_location': 'C9',
#   'column': 'C',
#   'row': 9,
#   'value': 2,
#   'formula': None,
#   'precedents': ['D10', 'C12'],
#   'dependencies': None,
#   'column_name': '2019-12-31',
#   'row_name': None,
#   'precedents_names': ['D10', 'C12'],
#   'dependent_names': []},
#  {'cell_location': 'D9',
#   'column': 'D',
#   'row': 9,
#   'value': 2.1,
#   'formula': None,
#   'precedents': ['D10', 'E10', 'D12'],
#   'dependencies': None,
#   'column_name': '2020-12-31',
#   'row_name': None,
#   'precedents_names': ['D10', 'E10', 'D12'],
#   'dependent_names': []},
#  {'cell_location': 'E9',
#   'column': 'E',
#   'row': 9,
#   'value': 2.15,
#   'formula': None,
#   'precedents': ['F9', 'E10', 'E12'],
#   'dependencies': None,
#   'column_name': '2021-12-31',
#   'row_name': None,
#   'precedents_names': ['F9', 'E10', 'E12'],
#   'dependent_names': []},
#  {'cell_location': 'F9',
#   'column': 'F',
#   'row': 9,
#   'value': 2.2145,
#   'formula': '=E9*(1+F10)',
#   'precedents': ['G9', 'F55'],
#   'dependencies': ['E9', 'F10'],
#   'column_name': '2022-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=E9*(1+F10)',
#   'precedents_names': ['G9', 'Services:'],
#   'dependent_names': ['E9', 'F10']},
#  {'cell_location': 'G9',
#   'column': 'G',
#   'row': 9,
#   'value': 2.2809350000000004,
#   'formula': '=F9*(1+G10)',
#   'precedents': ['H9', 'G55'],
#   'dependencies': ['F9', 'G10'],
#   'column_name': '2023-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=F9*(1+G10)',
#   'precedents_names': ['H9', 'Services:'],
#   'dependent_names': ['F9', 'G10']},
#  {'cell_location': 'H9',
#   'column': 'H',
#   'row': 9,
#   'value': 2.3493630500000005,
#   'formula': '=G9*(1+H10)',
#   'precedents': ['I9', 'H55'],
#   'dependencies': ['G9', 'H10'],
#   'column_name': '2024-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=G9*(1+H10)',
#   'precedents_names': ['I9', 'Services:'],
#   'dependent_names': ['G9', 'H10']},
#  {'cell_location': 'I9',
#   'column': 'I',
#   'row': 9,
#   'value': 2.4198439415000004,
#   'formula': '=H9*(1+I10)',
#   'precedents': ['J9', 'I55'],
#   'dependencies': ['H9', 'I10'],
#   'column_name': '2025-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=H9*(1+I10)',
#   'precedents_names': ['J9', 'Services:'],
#   'dependent_names': ['H9', 'I10']},
#  {'cell_location': 'J9',
#   'column': 'J',
#   'row': 9,
#   'value': 2.4924392597450002,
#   'formula': '=I9*(1+J10)',
#   'precedents': ['J55'],
#   'dependencies': ['I9', 'J10'],
#   'column_name': '2026-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=I9*(1+J10)',
#   'precedents_names': ['Services:'],
#   'dependent_names': ['I9', 'J10']},
#  {'cell_location': 'B10',
#   'column': 'B',
#   'row': 10,
#   'value': 'Growth Rate:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None,
#   'precedents_names': [],
#   'dependent_names': []},
#  {'cell_location': 'D10',
#   'column': 'D',
#   'row': 10,
#   'value': 0.050000000000000044,
#   'formula': '=D9/C9-1',
#   'precedents': None,
#   'dependencies': ['D9', 'C9'],
#   'column_name': '2020-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=D9/C9-1',
#   'precedents_names': [],
#   'dependent_names': ['D9', 'C9']},
#  {'cell_location': 'E10',
#   'column': 'E',
#   'row': 10,
#   'value': 0.023809523809523725,
#   'formula': '=E9/D9-1',
#   'precedents': None,
#   'dependencies': ['E9', 'D9'],
#   'column_name': '2021-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=E9/D9-1',
#   'precedents_names': [],
#   'dependent_names': ['E9', 'D9']},
#  {'cell_location': 'F10',
#   'column': 'F',
#   'row': 10,
#   'value': 0.03,
#   'formula': None,
#   'precedents': ['F9'],
#   'dependencies': None,
#   'column_name': '2022-12-31',
#   'row_name': None,
#   'precedents_names': ['F9'],
#   'dependent_names': []},
#  {'cell_location': 'G10',
#   'column': 'G',
#   'row': 10,
#   'value': 0.03,
#   'formula': None,
#   'precedents': ['G9'],
#   'dependencies': None,
#   'column_name': '2023-12-31',
#   'row_name': None,
#   'precedents_names': ['G9'],
#   'dependent_names': []},
#  {'cell_location': 'H10',
#   'column': 'H',
#   'row': 10,
#   'value': 0.03,
#   'formula': None,
#   'precedents': ['H9'],
#   'dependencies': None,
#   'column_name': '2024-12-31',
#   'row_name': None,
#   'precedents_names': ['H9'],
#   'dependent_names': []},
#  {'cell_location': 'I10',
#   'column': 'I',
#   'row': 10,
#   'value': 0.03,
#   'formula': None,
#   'precedents': ['I9'],
#   'dependencies': None,
#   'column_name': '2025-12-31',
#   'row_name': None,
#   'precedents_names': ['I9'],
#   'dependent_names': []},
#  {'cell_location': 'J10',
#   'column': 'J',
#   'row': 10,
#   'value': 0.03,
#   'formula': None,
#   'precedents': ['J9'],
#   'dependencies': None,
#   'column_name': '2026-12-31',
#   'row_name': None,
#   'precedents_names': ['J9'],
#   'dependent_names': []},
#  {'cell_location': 'B12',
#   'column': 'B',
#   'row': 12,
#   'value': 'Revenue per Service Unit:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None,
#   'precedents_names': [],
#   'dependent_names': []},
#  {'cell_location': 'C12',
#   'column': 'C',
#   'row': 12,
#   'value': 3735,
#   'formula': '=C55/C9',
#   'precedents': ['D13'],
#   'dependencies': ['C55', 'C9'],
#   'column_name': '2019-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=Services:/C9',
#   'precedents_names': ['D13'],
#   'dependent_names': ['Services:', 'C9']},
#  {'cell_location': 'D12',
#   'column': 'D',
#   'row': 12,
#   'value': 3516.6666666666665,
#   'formula': '=D55/D9',
#   'precedents': ['D13', 'E13'],
#   'dependencies': ['D55', 'D9'],
#   'column_name': '2020-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=Services:/D9',
#   'precedents_names': ['D13', 'E13'],
#   'dependent_names': ['Services:', 'D9']},
#  {'cell_location': 'E12',
#   'column': 'E',
#   'row': 12,
#   'value': 3660.46511627907,
#   'formula': '=E55/E9',
#   'precedents': ['F12', 'E13'],
#   'dependencies': ['E55', 'E9'],
#   'column_name': '2021-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=Services:/E9',
#   'precedents_names': ['F12', 'E13'],
#   'dependent_names': ['Services:', 'E9']},
#  {'cell_location': 'F12',
#   'column': 'F',
#   'row': 12,
#   'value': 3806.8837209302333,
#   'formula': '=E12*(1+F13)',
#   'precedents': ['G12', 'F55'],
#   'dependencies': ['E12', 'F13'],
#   'column_name': '2022-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=E12*(1+F13)',
#   'precedents_names': ['G12', 'Services:'],
#   'dependent_names': ['E12', 'F13']},
#  {'cell_location': 'G12',
#   'column': 'G',
#   'row': 12,
#   'value': 3940.124651162791,
#   'formula': '=F12*(1+G13)',
#   'precedents': ['H12', 'G55'],
#   'dependencies': ['F12', 'G13'],
#   'column_name': '2023-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=F12*(1+G13)',
#   'precedents_names': ['H12', 'Services:'],
#   'dependent_names': ['F12', 'G13']},
#  {'cell_location': 'H12',
#   'column': 'H',
#   'row': 12,
#   'value': 4078.029013953488,
#   'formula': '=G12*(1+H13)',
#   'precedents': ['I12', 'H55'],
#   'dependencies': ['G12', 'H13'],
#   'column_name': '2024-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=G12*(1+H13)',
#   'precedents_names': ['I12', 'Services:'],
#   'dependent_names': ['G12', 'H13']},
#  {'cell_location': 'I12',
#   'column': 'I',
#   'row': 12,
#   'value': 4200.369884372093,
#   'formula': '=H12*(1+I13)',
#   'precedents': ['J12', 'I55'],
#   'dependencies': ['H12', 'I13'],
#   'column_name': '2025-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=H12*(1+I13)',
#   'precedents_names': ['J12', 'Services:'],
#   'dependent_names': ['H12', 'I13']},
#  {'cell_location': 'J12',
#   'column': 'J',
#   'row': 12,
#   'value': 4326.380980903256,
#   'formula': '=I12*(1+J13)',
#   'precedents': ['J55'],
#   'dependencies': ['I12', 'J13'],
#   'column_name': '2026-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=I12*(1+J13)',
#   'precedents_names': ['Services:'],
#   'dependent_names': ['I12', 'J13']},
#  {'cell_location': 'B13',
#   'column': 'B',
#   'row': 13,
#   'value': 'Growth Rate:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None,
#   'precedents_names': [],
#   'dependent_names': []},
#  {'cell_location': 'D13',
#   'column': 'D',
#   'row': 13,
#   'value': -0.058456046407853623,
#   'formula': '=D12/C12-1',
#   'precedents': None,
#   'dependencies': ['D12', 'C12'],
#   'column_name': '2020-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=D12/C12-1',
#   'precedents_names': [],
#   'dependent_names': ['D12', 'C12']},
#  {'cell_location': 'E13',
#   'column': 'E',
#   'row': 13,
#   'value': 0.04089055439215272,
#   'formula': '=E12/D12-1',
#   'precedents': None,
#   'dependencies': ['E12', 'D12'],
#   'column_name': '2021-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=E12/D12-1',
#   'precedents_names': [],
#   'dependent_names': ['E12', 'D12']},
#  {'cell_location': 'F13',
#   'column': 'F',
#   'row': 13,
#   'value': 0.04,
#   'formula': None,
#   'precedents': ['F12'],
#   'dependencies': None,
#   'column_name': '2022-12-31',
#   'row_name': None,
#   'precedents_names': ['F12'],
#   'dependent_names': []},
#  {'cell_location': 'G13',
#   'column': 'G',
#   'row': 13,
#   'value': 0.035,
#   'formula': None,
#   'precedents': ['G12'],
#   'dependencies': None,
#   'column_name': '2023-12-31',
#   'row_name': None,
#   'precedents_names': ['G12'],
#   'dependent_names': []},
#  {'cell_location': 'H13',
#   'column': 'H',
#   'row': 13,
#   'value': 0.035,
#   'formula': None,
#   'precedents': ['H12'],
#   'dependencies': None,
#   'column_name': '2024-12-31',
#   'row_name': None,
#   'precedents_names': ['H12'],
#   'dependent_names': []},
#  {'cell_location': 'I13',
#   'column': 'I',
#   'row': 13,
#   'value': 0.03,
#   'formula': None,
#   'precedents': ['I12'],
#   'dependencies': None,
#   'column_name': '2025-12-31',
#   'row_name': None,
#   'precedents_names': ['I12'],
#   'dependent_names': []},
#  {'cell_location': 'J13',
#   'column': 'J',
#   'row': 13,
#   'value': 0.03,
#   'formula': None,
#   'precedents': ['J12'],
#   'dependencies': None,
#   'column_name': '2026-12-31',
#   'row_name': None,
#   'precedents_names': ['J12'],
#   'dependent_names': []},
#  {'cell_location': 'B15',
#   'column': 'B',
#   'row': 15,
#   'value': 'Product - COGS % Revenue:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None,
#   'precedents_names': [],
#   'dependent_names': []},
#  {'cell_location': 'C15',
#   'column': 'C',
#   'row': 15,
#   'value': 0.8215297450424929,
#   'formula': '=-C58/C54',
#   'precedents': ['F15'],
#   'dependencies': ['C58', 'C54'],
#   'column_name': '2019-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=-Cost of Products:/Products:',
#   'precedents_names': ['F15'],
#   'dependent_names': ['Cost of Products:', 'Products:']},
#  {'cell_location': 'D15',
#   'column': 'D',
#   'row': 15,
#   'value': 0.8264755166635636,
#   'formula': '=-D58/D54',
#   'precedents': None,
#   'dependencies': ['D58', 'D54'],
#   'column_name': '2020-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=-Cost of Products:/Products:',
#   'precedents_names': [],
#   'dependent_names': ['Cost of Products:', 'Products:']},
#  {'cell_location': 'E15',
#   'column': 'E',
#   'row': 15,
#   'value': 0.823428749222153,
#   'formula': '=-E58/E54',
#   'precedents': ['F15'],
#   'dependencies': ['E58', 'E54'],
#   'column_name': '2021-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=-Cost of Products:/Products:',
#   'precedents_names': ['F15'],
#   'dependent_names': ['Cost of Products:', 'Products:']},
#  {'cell_location': 'F15',
#   'column': 'F',
#   'row': 15,
#   'value': 0.8238113369760698,
#   'formula': '=AVERAGE(C15:E15)',
#   'precedents': ['G15', 'F58'],
#   'dependencies': ['C15', 'E15'],
#   'column_name': '2022-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=AVERAGE(C15:E15)',
#   'precedents_names': ['G15', 'Cost of Products:'],
#   'dependent_names': ['C15', 'E15']},
#  {'cell_location': 'G15',
#   'column': 'G',
#   'row': 15,
#   'value': 0.8238113369760698,
#   'formula': '=F15',
#   'precedents': ['H15', 'G58'],
#   'dependencies': ['F15'],
#   'column_name': '2023-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=F15',
#   'precedents_names': ['H15', 'Cost of Products:'],
#   'dependent_names': ['F15']},
#  {'cell_location': 'H15',
#   'column': 'H',
#   'row': 15,
#   'value': 0.8238113369760698,
#   'formula': '=G15',
#   'precedents': ['I15', 'H58'],
#   'dependencies': ['G15'],
#   'column_name': '2024-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=G15',
#   'precedents_names': ['I15', 'Cost of Products:'],
#   'dependent_names': ['G15']},
#  {'cell_location': 'I15',
#   'column': 'I',
#   'row': 15,
#   'value': 0.8238113369760698,
#   'formula': '=H15',
#   'precedents': ['J15', 'I58'],
#   'dependencies': ['H15'],
#   'column_name': '2025-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=H15',
#   'precedents_names': ['J15', 'Cost of Products:'],
#   'dependent_names': ['H15']},
#  {'cell_location': 'J15',
#   'column': 'J',
#   'row': 15,
#   'value': 0.8238113369760698,
#   'formula': '=I15',
#   'precedents': ['J58'],
#   'dependencies': ['I15'],
#   'column_name': '2026-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=I15',
#   'precedents_names': ['Cost of Products:'],
#   'dependent_names': ['I15']},
#  {'cell_location': 'B16',
#   'column': 'B',
#   'row': 16,
#   'value': 'Service - COGS % Revenue:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None,
#   'precedents_names': [],
#   'dependent_names': []},
#  {'cell_location': 'C16',
#   'column': 'C',
#   'row': 16,
#   'value': 0.6227576974564927,
#   'formula': '=-C59/C55',
#   'precedents': ['F16'],
#   'dependencies': ['C59', 'C55'],
#   'column_name': '2019-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=-Cost of Services:/Services:',
#   'precedents_names': ['F16'],
#   'dependent_names': ['Cost of Services:', 'Services:']},
#  {'cell_location': 'D16',
#   'column': 'D',
#   'row': 16,
#   'value': 0.6144888287068382,
#   'formula': '=-D59/D55',
#   'precedents': None,
#   'dependencies': ['D59', 'D55'],
#   'column_name': '2020-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=-Cost of Services:/Services:',
#   'precedents_names': [],
#   'dependent_names': ['Cost of Services:', 'Services:']},
#  {'cell_location': 'E16',
#   'column': 'E',
#   'row': 16,
#   'value': 0.61143583227446,
#   'formula': '=-E59/E55',
#   'precedents': ['F16'],
#   'dependencies': ['E59', 'E55'],
#   'column_name': '2021-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=-Cost of Services:/Services:',
#   'precedents_names': ['F16'],
#   'dependent_names': ['Cost of Services:', 'Services:']},
#  {'cell_location': 'F16',
#   'column': 'F',
#   'row': 16,
#   'value': 0.6162274528125969,
#   'formula': '=AVERAGE(C16:E16)',
#   'precedents': ['G16', 'F59'],
#   'dependencies': ['C16', 'E16'],
#   'column_name': '2022-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=AVERAGE(C16:E16)',
#   'precedents_names': ['G16', 'Cost of Services:'],
#   'dependent_names': ['C16', 'E16']},
#  {'cell_location': 'G16',
#   'column': 'G',
#   'row': 16,
#   'value': 0.6162274528125969,
#   'formula': '=F16',
#   'precedents': ['H16', 'G59'],
#   'dependencies': ['F16'],
#   'column_name': '2023-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=F16',
#   'precedents_names': ['H16', 'Cost of Services:'],
#   'dependent_names': ['F16']},
#  {'cell_location': 'H16',
#   'column': 'H',
#   'row': 16,
#   'value': 0.6162274528125969,
#   'formula': '=G16',
#   'precedents': ['I16', 'H59'],
#   'dependencies': ['G16'],
#   'column_name': '2024-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=G16',
#   'precedents_names': ['I16', 'Cost of Services:'],
#   'dependent_names': ['G16']},
#  {'cell_location': 'I16',
#   'column': 'I',
#   'row': 16,
#   'value': 0.6162274528125969,
#   'formula': '=H16',
#   'precedents': ['J16', 'I59'],
#   'dependencies': ['H16'],
#   'column_name': '2025-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=H16',
#   'precedents_names': ['J16', 'Cost of Services:'],
#   'dependent_names': ['H16']},
#  {'cell_location': 'J16',
#   'column': 'J',
#   'row': 16,
#   'value': 0.6162274528125969,
#   'formula': '=I16',
#   'precedents': ['J59'],
#   'dependencies': ['I16'],
#   'column_name': '2026-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=I16',
#   'precedents_names': ['Cost of Services:'],
#   'dependent_names': ['I16']},
#  {'cell_location': 'B17',
#   'column': 'B',
#   'row': 17,
#   'value': 'OpEx % Revenue:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None,
#   'precedents_names': [],
#   'dependent_names': []},
#  {'cell_location': 'C17',
#   'column': 'C',
#   'row': 17,
#   'value': 0.15040402500381156,
#   'formula': '=-C60/C56',
#   'precedents': ['F17'],
#   'dependencies': ['C60', 'C56'],
#   'column_name': '2019-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=-Operating Expenses:/Total Revenue:',
#   'precedents_names': ['F17'],
#   'dependent_names': ['Operating Expenses:', 'Total Revenue:']},
#  {'cell_location': 'D17',
#   'column': 'D',
#   'row': 17,
#   'value': 0.1627469426152399,
#   'formula': '=-D60/D56',
#   'precedents': None,
#   'dependencies': ['D60', 'D56'],
#   'column_name': '2020-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=-Operating Expenses:/Total Revenue:',
#   'precedents_names': [],
#   'dependent_names': ['Operating Expenses:', 'Total Revenue:']},
#  {'cell_location': 'E17',
#   'column': 'E',
#   'row': 17,
#   'value': 0.1473632675898727,
#   'formula': '=-E60/E56',
#   'precedents': ['F17'],
#   'dependencies': ['E60', 'E56'],
#   'column_name': '2021-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=-Operating Expenses:/Total Revenue:',
#   'precedents_names': ['F17'],
#   'dependent_names': ['Operating Expenses:', 'Total Revenue:']},
#  {'cell_location': 'F17',
#   'column': 'F',
#   'row': 17,
#   'value': 0.1535047450696414,
#   'formula': '=AVERAGE(C17:E17)',
#   'precedents': ['G17', 'F60'],
#   'dependencies': ['C17', 'E17'],
#   'column_name': '2022-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=AVERAGE(C17:E17)',
#   'precedents_names': ['G17', 'Operating Expenses:'],
#   'dependent_names': ['C17', 'E17']},
#  {'cell_location': 'G17',
#   'column': 'G',
#   'row': 17,
#   'value': 0.1535047450696414,
#   'formula': '=F17',
#   'precedents': ['H17', 'G60'],
#   'dependencies': ['F17'],
#   'column_name': '2023-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=F17',
#   'precedents_names': ['H17', 'Operating Expenses:'],
#   'dependent_names': ['F17']},
#  {'cell_location': 'H17',
#   'column': 'H',
#   'row': 17,
#   'value': 0.1535047450696414,
#   'formula': '=G17',
#   'precedents': ['I17', 'H60'],
#   'dependencies': ['G17'],
#   'column_name': '2024-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=G17',
#   'precedents_names': ['I17', 'Operating Expenses:'],
#   'dependent_names': ['G17']},
#  {'cell_location': 'I17',
#   'column': 'I',
#   'row': 17,
#   'value': 0.1535047450696414,
#   'formula': '=H17',
#   'precedents': ['J17', 'I60'],
#   'dependencies': ['H17'],
#   'column_name': '2025-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=H17',
#   'precedents_names': ['J17', 'Operating Expenses:'],
#   'dependent_names': ['H17']},
#  {'cell_location': 'J17',
#   'column': 'J',
#   'row': 17,
#   'value': 0.1535047450696414,
#   'formula': '=I17',
#   'precedents': ['J60'],
#   'dependencies': ['I17'],
#   'column_name': '2026-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=I17',
#   'precedents_names': ['Operating Expenses:'],
#   'dependent_names': ['I17']},
#  {'cell_location': 'B19',
#   'column': 'B',
#   'row': 19,
#   'value': 'Tax Rate:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None,
#   'precedents_names': [],
#   'dependent_names': []},
#  {'cell_location': 'C19',
#   'column': 'C',
#   'row': 19,
#   'value': 0.3191832348199892,
#   'formula': '=-C68/C66',
#   'precedents': ['F19'],
#   'dependencies': ['C68', 'C66'],
#   'column_name': '2019-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=-Income Taxes:/Pre‐Tax Income:',
#   'precedents_names': ['F19'],
#   'dependent_names': ['Income Taxes:', 'Pre‐Tax Income:']},
#  {'cell_location': 'D19',
#   'column': 'D',
#   'row': 19,
#   'value': 0.3011250827266711,
#   'formula': '=-D68/D66',
#   'precedents': None,
#   'dependencies': ['D68', 'D66'],
#   'column_name': '2020-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=-Income Taxes:/Pre‐Tax Income:',
#   'precedents_names': [],
#   'dependent_names': ['Income Taxes:', 'Pre‐Tax Income:']},
#  {'cell_location': 'E19',
#   'column': 'E',
#   'row': 19,
#   'value': 0.2758796532381438,
#   'formula': '=-E68/E66',
#   'precedents': ['F19'],
#   'dependencies': ['E68', 'E66'],
#   'column_name': '2021-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=-Income Taxes:/Pre‐Tax Income:',
#   'precedents_names': ['F19'],
#   'dependent_names': ['Income Taxes:', 'Pre‐Tax Income:']},
#  {'cell_location': 'F19',
#   'column': 'F',
#   'row': 19,
#   'value': 0.2987293235949347,
#   'formula': '=AVERAGE(C19:E19)',
#   'precedents': ['G19', 'F68'],
#   'dependencies': ['C19', 'E19'],
#   'column_name': '2022-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=AVERAGE(C19:E19)',
#   'precedents_names': ['G19', 'Income Taxes:'],
#   'dependent_names': ['C19', 'E19']},
#  {'cell_location': 'G19',
#   'column': 'G',
#   'row': 19,
#   'value': 0.2987293235949347,
#   'formula': '=F19',
#   'precedents': ['H19', 'G68'],
#   'dependencies': ['F19'],
#   'column_name': '2023-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=F19',
#   'precedents_names': ['H19', 'Income Taxes:'],
#   'dependent_names': ['F19']},
#  {'cell_location': 'H19',
#   'column': 'H',
#   'row': 19,
#   'value': 0.2987293235949347,
#   'formula': '=G19',
#   'precedents': ['I19', 'H68'],
#   'dependencies': ['G19'],
#   'column_name': '2024-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=G19',
#   'precedents_names': ['I19', 'Income Taxes:'],
#   'dependent_names': ['G19']},
#  {'cell_location': 'I19',
#   'column': 'I',
#   'row': 19,
#   'value': 0.2987293235949347,
#   'formula': '=H19',
#   'precedents': ['J19', 'I68'],
#   'dependencies': ['H19'],
#   'column_name': '2025-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=H19',
#   'precedents_names': ['J19', 'Income Taxes:'],
#   'dependent_names': ['H19']},
#  {'cell_location': 'J19',
#   'column': 'J',
#   'row': 19,
#   'value': 0.2987293235949347,
#   'formula': '=I19',
#   'precedents': ['J68'],
#   'dependencies': ['I19'],
#   'column_name': '2026-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=I19',
#   'precedents_names': ['Income Taxes:'],
#   'dependent_names': ['I19']},
#  {'cell_location': 'B20',
#   'column': 'B',
#   'row': 20,
#   'value': 'NCI Net Income % Total:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None,
#   'precedents_names': [],
#   'dependent_names': []},
#  {'cell_location': 'C20',
#   'column': 'C',
#   'row': 20,
#   'value': 0.11917916337805841,
#   'formula': '=-C71/C70',
#   'precedents': ['F20'],
#   'dependencies': ['C71', 'C70'],
#   'column_name': '2019-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=-(-) NCI Net Income:/Net Income:',
#   'precedents_names': ['F20'],
#   'dependent_names': ['(-) NCI Net Income:', 'Net Income:']},
#  {'cell_location': 'D20',
#   'column': 'D',
#   'row': 20,
#   'value': 0.14204545454545456,
#   'formula': '=-D71/D70',
#   'precedents': None,
#   'dependencies': ['D71', 'D70'],
#   'column_name': '2020-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=-(-) NCI Net Income:/Net Income:',
#   'precedents_names': [],
#   'dependent_names': ['(-) NCI Net Income:', 'Net Income:']},
#  {'cell_location': 'E20',
#   'column': 'E',
#   'row': 20,
#   'value': 0.12253521126760564,
#   'formula': '=-E71/E70',
#   'precedents': ['F20'],
#   'dependencies': ['E71', 'E70'],
#   'column_name': '2021-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=-(-) NCI Net Income:/Net Income:',
#   'precedents_names': ['F20'],
#   'dependent_names': ['(-) NCI Net Income:', 'Net Income:']},
#  {'cell_location': 'F20',
#   'column': 'F',
#   'row': 20,
#   'value': 0.12791994306370622,
#   'formula': '=AVERAGE(C20:E20)',
#   'precedents': ['G20', 'F71'],
#   'dependencies': ['C20', 'E20'],
#   'column_name': '2022-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=AVERAGE(C20:E20)',
#   'precedents_names': ['G20', '(-) NCI Net Income:'],
#   'dependent_names': ['C20', 'E20']},
#  {'cell_location': 'G20',
#   'column': 'G',
#   'row': 20,
#   'value': 0.12791994306370622,
#   'formula': '=F20',
#   'precedents': ['H20', 'G71'],
#   'dependencies': ['F20'],
#   'column_name': '2023-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=F20',
#   'precedents_names': ['H20', '(-) NCI Net Income:'],
#   'dependent_names': ['F20']},
#  {'cell_location': 'H20',
#   'column': 'H',
#   'row': 20,
#   'value': 0.12791994306370622,
#   'formula': '=G20',
#   'precedents': ['I20', 'H71'],
#   'dependencies': ['G20'],
#   'column_name': '2024-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=G20',
#   'precedents_names': ['I20', '(-) NCI Net Income:'],
#   'dependent_names': ['G20']},
#  {'cell_location': 'I20',
#   'column': 'I',
#   'row': 20,
#   'value': 0.12791994306370622,
#   'formula': '=H20',
#   'precedents': ['J20', 'I71'],
#   'dependencies': ['H20'],
#   'column_name': '2025-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=H20',
#   'precedents_names': ['J20', '(-) NCI Net Income:'],
#   'dependent_names': ['H20']},
#  {'cell_location': 'J20',
#   'column': 'J',
#   'row': 20,
#   'value': 0.12791994306370622,
#   'formula': '=I20',
#   'precedents': ['J71'],
#   'dependencies': ['I20'],
#   'column_name': '2026-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=I20',
#   'precedents_names': ['(-) NCI Net Income:'],
#   'dependent_names': ['I20']},
#  {'cell_location': 'B22',
#   'column': 'B',
#   'row': 22,
#   'value': 'Accounts Receivable % Revenue:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None,
#   'precedents_names': [],
#   'dependent_names': []},
#  {'cell_location': 'D22',
#   'column': 'D',
#   'row': 22,
#   'value': 0.24678582627783005,
#   'formula': '=D78/D56',
#   'precedents': None,
#   'dependencies': ['D78', 'D56'],
#   'column_name': '2020-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=Accounts Receivable:/Total Revenue:',
#   'precedents_names': [],
#   'dependent_names': ['Accounts Receivable:', 'Total Revenue:']},
#  {'cell_location': 'E22',
#   'column': 'E',
#   'row': 22,
#   'value': 0.22604560078332633,
#   'formula': '=E78/E56',
#   'precedents': ['F22'],
#   'dependencies': ['E78', 'E56'],
#   'column_name': '2021-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=Accounts Receivable:/Total Revenue:',
#   'precedents_names': ['F22'],
#   'dependent_names': ['Accounts Receivable:', 'Total Revenue:']},
#  {'cell_location': 'F22',
#   'column': 'F',
#   'row': 22,
#   'value': 0.2364157135305782,
#   'formula': '=AVERAGE(C22:E22)',
#   'precedents': ['G22', 'F78'],
#   'dependencies': ['C22', 'E22'],
#   'column_name': '2022-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=AVERAGE(C22:E22)',
#   'precedents_names': ['G22', 'Accounts Receivable:'],
#   'dependent_names': ['C22', 'E22']},
#  {'cell_location': 'G22',
#   'column': 'G',
#   'row': 22,
#   'value': 0.2364157135305782,
#   'formula': '=F22',
#   'precedents': ['H22', 'G78'],
#   'dependencies': ['F22'],
#   'column_name': '2023-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=F22',
#   'precedents_names': ['H22', 'Accounts Receivable:'],
#   'dependent_names': ['F22']},
#  {'cell_location': 'H22',
#   'column': 'H',
#   'row': 22,
#   'value': 0.2364157135305782,
#   'formula': '=G22',
#   'precedents': ['I22', 'H78'],
#   'dependencies': ['G22'],
#   'column_name': '2024-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=G22',
#   'precedents_names': ['I22', 'Accounts Receivable:'],
#   'dependent_names': ['G22']},
#  {'cell_location': 'I22',
#   'column': 'I',
#   'row': 22,
#   'value': 0.2364157135305782,
#   'formula': '=H22',
#   'precedents': ['J22', 'I78'],
#   'dependencies': ['H22'],
#   'column_name': '2025-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=H22',
#   'precedents_names': ['J22', 'Accounts Receivable:'],
#   'dependent_names': ['H22']},
#  {'cell_location': 'J22',
#   'column': 'J',
#   'row': 22,
#   'value': 0.2364157135305782,
#   'formula': '=I22',
#   'precedents': ['J78'],
#   'dependencies': ['I22'],
#   'column_name': '2026-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=I22',
#   'precedents_names': ['Accounts Receivable:'],
#   'dependent_names': ['I22']},
#  {'cell_location': 'B23',
#   'column': 'B',
#   'row': 23,
#   'value': 'Inventory & Other % COGS:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None,
#   'precedents_names': [],
#   'dependent_names': []},
#  {'cell_location': 'D23',
#   'column': 'D',
#   'row': 23,
#   'value': 0.1722178901637518,
#   'formula': '=-D79/SUM(D58:D59)',
#   'precedents': None,
#   'dependencies': ['D79', 'D58', 'D59'],
#   'column_name': '2020-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=-Inventory & Other:/SUM(Cost of Products::Cost of Services:)',
#   'precedents_names': [],
#   'dependent_names': ['Inventory & Other:',
#    'Cost of Products:',
#    'Cost of Services:']},
#  {'cell_location': 'E23',
#   'column': 'E',
#   'row': 23,
#   'value': 0.15378525482434438,
#   'formula': '=-E79/SUM(E58:E59)',
#   'precedents': ['F23'],
#   'dependencies': ['E79', 'E58', 'E59'],
#   'column_name': '2021-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=-Inventory & Other:/SUM(Cost of Products::Cost of Services:)',
#   'precedents_names': ['F23'],
#   'dependent_names': ['Inventory & Other:',
#    'Cost of Products:',
#    'Cost of Services:']},
#  {'cell_location': 'F23',
#   'column': 'F',
#   'row': 23,
#   'value': 0.1630015724940481,
#   'formula': '=AVERAGE(C23:E23)',
#   'precedents': ['G23', 'F79'],
#   'dependencies': ['C23', 'E23'],
#   'column_name': '2022-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=AVERAGE(C23:E23)',
#   'precedents_names': ['G23', 'Inventory & Other:'],
#   'dependent_names': ['C23', 'E23']},
#  {'cell_location': 'G23',
#   'column': 'G',
#   'row': 23,
#   'value': 0.1630015724940481,
#   'formula': '=F23',
#   'precedents': ['H23', 'G79'],
#   'dependencies': ['F23'],
#   'column_name': '2023-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=F23',
#   'precedents_names': ['H23', 'Inventory & Other:'],
#   'dependent_names': ['F23']},
#  {'cell_location': 'H23',
#   'column': 'H',
#   'row': 23,
#   'value': 0.1630015724940481,
#   'formula': '=G23',
#   'precedents': ['I23', 'H79'],
#   'dependencies': ['G23'],
#   'column_name': '2024-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=G23',
#   'precedents_names': ['I23', 'Inventory & Other:'],
#   'dependent_names': ['G23']},
#  {'cell_location': 'I23',
#   'column': 'I',
#   'row': 23,
#   'value': 0.1630015724940481,
#   'formula': '=H23',
#   'precedents': ['J23', 'I79'],
#   'dependencies': ['H23'],
#   'column_name': '2025-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=H23',
#   'precedents_names': ['J23', 'Inventory & Other:'],
#   'dependent_names': ['H23']},
#  {'cell_location': 'J23',
#   'column': 'J',
#   'row': 23,
#   'value': 0.1630015724940481,
#   'formula': '=I23',
#   'precedents': ['J79'],
#   'dependencies': ['I23'],
#   'column_name': '2026-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=I23',
#   'precedents_names': ['Inventory & Other:'],
#   'dependent_names': ['I23']},
#  {'cell_location': 'B24',
#   'column': 'B',
#   'row': 24,
#   'value': 'Op. Lease Assets % OpEx:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None,
#   'precedents_names': [],
#   'dependent_names': []},
#  {'cell_location': 'D24',
#   'column': 'D',
#   'row': 24,
#   'value': 0.2610789980732177,
#   'formula': '=-D81/D60',
#   'precedents': None,
#   'dependencies': ['D81', 'D60'],
#   'column_name': '2020-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=-Op. Lease Assets:/Operating Expenses:',
#   'precedents_names': [],
#   'dependent_names': ['Op. Lease Assets:', 'Operating Expenses:']},
#  {'cell_location': 'E24',
#   'column': 'E',
#   'row': 24,
#   'value': 0.24964404366397722,
#   'formula': '=-E81/E60',
#   'precedents': ['F24'],
#   'dependencies': ['E81', 'E60'],
#   'column_name': '2021-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=-Op. Lease Assets:/Operating Expenses:',
#   'precedents_names': ['F24'],
#   'dependent_names': ['Op. Lease Assets:', 'Operating Expenses:']},
#  {'cell_location': 'F24',
#   'column': 'F',
#   'row': 24,
#   'value': 0.2553615208685975,
#   'formula': '=AVERAGE(C24:E24)',
#   'precedents': ['G24', 'F81'],
#   'dependencies': ['C24', 'E24'],
#   'column_name': '2022-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=AVERAGE(C24:E24)',
#   'precedents_names': ['G24', 'Op. Lease Assets:'],
#   'dependent_names': ['C24', 'E24']},
#  {'cell_location': 'G24',
#   'column': 'G',
#   'row': 24,
#   'value': 0.2553615208685975,
#   'formula': '=F24',
#   'precedents': ['H24', 'G81'],
#   'dependencies': ['F24'],
#   'column_name': '2023-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=F24',
#   'precedents_names': ['H24', 'Op. Lease Assets:'],
#   'dependent_names': ['F24']},
#  {'cell_location': 'H24',
#   'column': 'H',
#   'row': 24,
#   'value': 0.2553615208685975,
#   'formula': '=G24',
#   'precedents': ['I24', 'H81'],
#   'dependencies': ['G24'],
#   'column_name': '2024-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=G24',
#   'precedents_names': ['I24', 'Op. Lease Assets:'],
#   'dependent_names': ['G24']},
#  {'cell_location': 'I24',
#   'column': 'I',
#   'row': 24,
#   'value': 0.2553615208685975,
#   'formula': '=H24',
#   'precedents': ['J24', 'I81'],
#   'dependencies': ['H24'],
#   'column_name': '2025-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=H24',
#   'precedents_names': ['J24', 'Op. Lease Assets:'],
#   'dependent_names': ['H24']},
#  {'cell_location': 'J24',
#   'column': 'J',
#   'row': 24,
#   'value': 0.2553615208685975,
#   'formula': '=I24',
#   'precedents': ['J81'],
#   'dependencies': ['I24'],
#   'column_name': '2026-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=I24',
#   'precedents_names': ['Op. Lease Assets:'],
#   'dependent_names': ['I24']},
#  {'cell_location': 'B26',
#   'column': 'B',
#   'row': 26,
#   'value': 'Accounts Payable % COGS:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None,
#   'precedents_names': [],
#   'dependent_names': []},
#  {'cell_location': 'D26',
#   'column': 'D',
#   'row': 26,
#   'value': 0.1618580817645093,
#   'formula': '=-D86/SUM(D58:D59)',
#   'precedents': None,
#   'dependencies': ['D86', 'D58', 'D59'],
#   'column_name': '2020-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=-Accounts Payable:/SUM(Cost of Products::Cost of Services:)',
#   'precedents_names': [],
#   'dependent_names': ['Accounts Payable:',
#    'Cost of Products:',
#    'Cost of Services:']},
#  {'cell_location': 'E26',
#   'column': 'E',
#   'row': 26,
#   'value': 0.15398317664522512,
#   'formula': '=-E86/SUM(E58:E59)',
#   'precedents': ['F26'],
#   'dependencies': ['E86', 'E58', 'E59'],
#   'column_name': '2021-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=-Accounts Payable:/SUM(Cost of Products::Cost of Services:)',
#   'precedents_names': ['F26'],
#   'dependent_names': ['Accounts Payable:',
#    'Cost of Products:',
#    'Cost of Services:']},
#  {'cell_location': 'F26',
#   'column': 'F',
#   'row': 26,
#   'value': 0.1579206292048672,
#   'formula': '=AVERAGE(C26:E26)',
#   'precedents': ['G26', 'F86'],
#   'dependencies': ['C26', 'E26'],
#   'column_name': '2022-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=AVERAGE(C26:E26)',
#   'precedents_names': ['G26', 'Accounts Payable:'],
#   'dependent_names': ['C26', 'E26']},
#  {'cell_location': 'G26',
#   'column': 'G',
#   'row': 26,
#   'value': 0.1579206292048672,
#   'formula': '=F26',
#   'precedents': ['H26', 'G86'],
#   'dependencies': ['F26'],
#   'column_name': '2023-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=F26',
#   'precedents_names': ['H26', 'Accounts Payable:'],
#   'dependent_names': ['F26']},
#  {'cell_location': 'H26',
#   'column': 'H',
#   'row': 26,
#   'value': 0.1579206292048672,
#   'formula': '=G26',
#   'precedents': ['I26', 'H86'],
#   'dependencies': ['G26'],
#   'column_name': '2024-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=G26',
#   'precedents_names': ['I26', 'Accounts Payable:'],
#   'dependent_names': ['G26']},
#  {'cell_location': 'I26',
#   'column': 'I',
#   'row': 26,
#   'value': 0.1579206292048672,
#   'formula': '=H26',
#   'precedents': ['J26', 'I86'],
#   'dependencies': ['H26'],
#   'column_name': '2025-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=H26',
#   'precedents_names': ['J26', 'Accounts Payable:'],
#   'dependent_names': ['H26']},
#  {'cell_location': 'J26',
#   'column': 'J',
#   'row': 26,
#   'value': 0.1579206292048672,
#   'formula': '=I26',
#   'precedents': ['J86'],
#   'dependencies': ['I26'],
#   'column_name': '2026-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=I26',
#   'precedents_names': ['Accounts Payable:'],
#   'dependent_names': ['I26']},
#  {'cell_location': 'B27',
#   'column': 'B',
#   'row': 27,
#   'value': 'Accrued Liabilities % Total Expenses:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': None,
#   'precedents_names': [],
#   'dependent_names': []},
#  {'cell_location': 'D27',
#   'column': 'D',
#   'row': 27,
#   'value': 0.1788654663892156,
#   'formula': '=-D87/SUM(D58:D60)',
#   'precedents': None,
#   'dependencies': ['D87', 'D58', 'D60'],
#   'column_name': '2020-12-31',
#   'row_name': None,
#   'formula_with_row_names': '=-Accrued Liabilities:/SUM(Cost of Products::Operating Expenses:)',
#   'precedents_names': [],
#   'dependent_names': ['Accrued Liabilities:',
#    'Cost of Products:',
#    'Operating Expenses:']},
#  {'cell_location': 'E27',
#   'column': 'E',
#   'row': 27,
#   'value': 0.16320013101867015,
#   'formula': '=-E87/SUM(E58:E60)',
#   'precedents': ['F27'],
#   'dependencies': ['E87', 'E58', 'E60'],
# ...
#   'dependent_names': ['(+/-) Reversal of NCI Net Income:', 'I47']},
#  {'cell_location': 'J120',
#   'column': 'J',
#   'row': 120,
#   'value': -217.0074142874306,
#   'formula': '=-J105*J47',
#   'precedents': ['J38', 'J95'],
#   'dependencies': ['J105', 'J47'],
#   'column_name': '2026-12-31',
#   'row_name': '(-) Dividends to NCI:',
#   'formula_with_row_names': '=-(+/-) Reversal of NCI Net Income:*J47',
#   'precedents_names': ['J38', 'Noncontrolling Interests:'],
#   'dependent_names': ['(+/-) Reversal of NCI Net Income:', 'J47']},
#  {'cell_location': 'B121',
#   'column': 'B',
#   'row': 121,
#   'value': '(+/-) Other Items:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': '(+/-) Other Items:',
#   'precedents_names': [],
#   'dependent_names': []},
#  {'cell_location': 'C121',
#   'column': 'C',
#   'row': 121,
#   'value': -976,
#   'formula': None,
#   'precedents': ['C122'],
#   'dependencies': None,
#   'column_name': '2019-12-31',
#   'row_name': '(+/-) Other Items:',
#   'precedents_names': ['Cash Flow from Financing:'],
#   'dependent_names': []},
#  {'cell_location': 'D121',
#   'column': 'D',
#   'row': 121,
#   'value': -6382,
#   'formula': None,
#   'precedents': ['D122'],
#   'dependencies': None,
#   'column_name': '2020-12-31',
#   'row_name': '(+/-) Other Items:',
#   'precedents_names': ['Cash Flow from Financing:'],
#   'dependent_names': []},
#  {'cell_location': 'E121',
#   'column': 'E',
#   'row': 121,
#   'value': -44,
#   'formula': None,
#   'precedents': ['E49', 'E122'],
#   'dependencies': None,
#   'column_name': '2021-12-31',
#   'row_name': '(+/-) Other Items:',
#   'precedents_names': ['E49', 'Cash Flow from Financing:'],
#   'dependent_names': []},
#  {'cell_location': 'F121',
#   'column': 'F',
#   'row': 121,
#   'value': 0,
#   'formula': '=MAX(F117,0)*F49',
#   'precedents': ['F94', 'F122'],
#   'dependencies': ['F117', 'F49'],
#   'column_name': '2022-12-31',
#   'row_name': '(+/-) Other Items:',
#   'formula_with_row_names': '=MAX((+/-) Change in Debt:,0)*F49',
#   'precedents_names': ["Common Shareholders' Equity:",
#    'Cash Flow from Financing:'],
#   'dependent_names': ['(+/-) Change in Debt:', 'F49']},
#  {'cell_location': 'G121',
#   'column': 'G',
#   'row': 121,
#   'value': 0,
#   'formula': '=MAX(G117,0)*G49',
#   'precedents': ['G94', 'G122'],
#   'dependencies': ['G117', 'G49'],
#   'column_name': '2023-12-31',
#   'row_name': '(+/-) Other Items:',
#   'formula_with_row_names': '=MAX((+/-) Change in Debt:,0)*G49',
#   'precedents_names': ["Common Shareholders' Equity:",
#    'Cash Flow from Financing:'],
#   'dependent_names': ['(+/-) Change in Debt:', 'G49']},
#  {'cell_location': 'H121',
#   'column': 'H',
#   'row': 121,
#   'value': 0,
#   'formula': '=MAX(H117,0)*H49',
#   'precedents': ['H94', 'H122'],
#   'dependencies': ['H117', 'H49'],
#   'column_name': '2024-12-31',
#   'row_name': '(+/-) Other Items:',
#   'formula_with_row_names': '=MAX((+/-) Change in Debt:,0)*H49',
#   'precedents_names': ["Common Shareholders' Equity:",
#    'Cash Flow from Financing:'],
#   'dependent_names': ['(+/-) Change in Debt:', 'H49']},
#  {'cell_location': 'I121',
#   'column': 'I',
#   'row': 121,
#   'value': 0,
#   'formula': '=MAX(I117,0)*I49',
#   'precedents': ['I94', 'I122'],
#   'dependencies': ['I117', 'I49'],
#   'column_name': '2025-12-31',
#   'row_name': '(+/-) Other Items:',
#   'formula_with_row_names': '=MAX((+/-) Change in Debt:,0)*I49',
#   'precedents_names': ["Common Shareholders' Equity:",
#    'Cash Flow from Financing:'],
#   'dependent_names': ['(+/-) Change in Debt:', 'I49']},
#  {'cell_location': 'J121',
#   'column': 'J',
#   'row': 121,
#   'value': 0,
#   'formula': '=MAX(J117,0)*J49',
#   'precedents': ['J94', 'J122'],
#   'dependencies': ['J117', 'J49'],
#   'column_name': '2026-12-31',
#   'row_name': '(+/-) Other Items:',
#   'formula_with_row_names': '=MAX((+/-) Change in Debt:,0)*J49',
#   'precedents_names': ["Common Shareholders' Equity:",
#    'Cash Flow from Financing:'],
#   'dependent_names': ['(+/-) Change in Debt:', 'J49']},
#  {'cell_location': 'B122',
#   'column': 'B',
#   'row': 122,
#   'value': 'Cash Flow from Financing:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': 'Cash Flow from Financing:',
#   'precedents_names': [],
#   'dependent_names': []},
#  {'cell_location': 'C122',
#   'column': 'C',
#   'row': 122,
#   'value': -1133,
#   'formula': '=SUM(C117:C121)',
#   'precedents': ['C126'],
#   'dependencies': ['C117', 'C121'],
#   'column_name': '2019-12-31',
#   'row_name': 'Cash Flow from Financing:',
#   'formula_with_row_names': '=SUM((+/-) Change in Debt::(+/-) Other Items:)',
#   'precedents_names': ['Net Change in Cash:'],
#   'dependent_names': ['(+/-) Change in Debt:', '(+/-) Other Items:']},
#  {'cell_location': 'D122',
#   'column': 'D',
#   'row': 122,
#   'value': -844,
#   'formula': '=SUM(D117:D121)',
#   'precedents': ['D126'],
#   'dependencies': ['D117', 'D121'],
#   'column_name': '2020-12-31',
#   'row_name': 'Cash Flow from Financing:',
#   'formula_with_row_names': '=SUM((+/-) Change in Debt::(+/-) Other Items:)',
#   'precedents_names': ['Net Change in Cash:'],
#   'dependent_names': ['(+/-) Change in Debt:', '(+/-) Other Items:']},
#  {'cell_location': 'E122',
#   'column': 'E',
#   'row': 122,
#   'value': 58,
#   'formula': '=SUM(E117:E121)',
#   'precedents': ['E126'],
#   'dependencies': ['E117', 'E121'],
#   'column_name': '2021-12-31',
#   'row_name': 'Cash Flow from Financing:',
#   'formula_with_row_names': '=SUM((+/-) Change in Debt::(+/-) Other Items:)',
#   'precedents_names': ['Net Change in Cash:'],
#   'dependent_names': ['(+/-) Change in Debt:', '(+/-) Other Items:']},
#  {'cell_location': 'F122',
#   'column': 'F',
#   'row': 122,
#   'value': -2236.804418385149,
#   'formula': '=SUM(F117:F121)',
#   'precedents': ['F126'],
#   'dependencies': ['F117', 'F121'],
#   'column_name': '2022-12-31',
#   'row_name': 'Cash Flow from Financing:',
#   'formula_with_row_names': '=SUM((+/-) Change in Debt::(+/-) Other Items:)',
#   'precedents_names': ['Net Change in Cash:'],
#   'dependent_names': ['(+/-) Change in Debt:', '(+/-) Other Items:']},
#  {'cell_location': 'G122',
#   'column': 'G',
#   'row': 122,
#   'value': -1668.30745259737,
#   'formula': '=SUM(G117:G121)',
#   'precedents': ['G126'],
#   'dependencies': ['G117', 'G121'],
#   'column_name': '2023-12-31',
#   'row_name': 'Cash Flow from Financing:',
#   'formula_with_row_names': '=SUM((+/-) Change in Debt::(+/-) Other Items:)',
#   'precedents_names': ['Net Change in Cash:'],
#   'dependent_names': ['(+/-) Change in Debt:', '(+/-) Other Items:']},
#  {'cell_location': 'H122',
#   'column': 'H',
#   'row': 122,
#   'value': -1772.9145020002447,
#   'formula': '=SUM(H117:H121)',
#   'precedents': ['H126'],
#   'dependencies': ['H117', 'H121'],
#   'column_name': '2024-12-31',
#   'row_name': 'Cash Flow from Financing:',
#   'formula_with_row_names': '=SUM((+/-) Change in Debt::(+/-) Other Items:)',
#   'precedents_names': ['Net Change in Cash:'],
#   'dependent_names': ['(+/-) Change in Debt:', '(+/-) Other Items:']},
#  {'cell_location': 'I122',
#   'column': 'I',
#   'row': 122,
#   'value': -1850.3424276613546,
#   'formula': '=SUM(I117:I121)',
#   'precedents': ['I126'],
#   'dependencies': ['I117', 'I121'],
#   'column_name': '2025-12-31',
#   'row_name': 'Cash Flow from Financing:',
#   'formula_with_row_names': '=SUM((+/-) Change in Debt::(+/-) Other Items:)',
#   'precedents_names': ['Net Change in Cash:'],
#   'dependent_names': ['(+/-) Change in Debt:', '(+/-) Other Items:']},
#  {'cell_location': 'J122',
#   'column': 'J',
#   'row': 122,
#   'value': -1940.3399302753464,
#   'formula': '=SUM(J117:J121)',
#   'precedents': ['J126'],
#   'dependencies': ['J117', 'J121'],
#   'column_name': '2026-12-31',
#   'row_name': 'Cash Flow from Financing:',
#   'formula_with_row_names': '=SUM((+/-) Change in Debt::(+/-) Other Items:)',
#   'precedents_names': ['Net Change in Cash:'],
#   'dependent_names': ['(+/-) Change in Debt:', '(+/-) Other Items:']},
#  {'cell_location': 'B124',
#   'column': 'B',
#   'row': 124,
#   'value': 'FX Rate Effects:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': 'FX Rate Effects:',
#   'precedents_names': [],
#   'dependent_names': []},
#  {'cell_location': 'C124',
#   'column': 'C',
#   'row': 124,
#   'value': -20,
#   'formula': None,
#   'precedents': ['C50', 'C126'],
#   'dependencies': None,
#   'column_name': '2019-12-31',
#   'row_name': 'FX Rate Effects:',
#   'precedents_names': ['C50', 'Net Change in Cash:'],
#   'dependent_names': []},
#  {'cell_location': 'D124',
#   'column': 'D',
#   'row': 124,
#   'value': 59,
#   'formula': None,
#   'precedents': ['D50', 'D126'],
#   'dependencies': None,
#   'column_name': '2020-12-31',
#   'row_name': 'FX Rate Effects:',
#   'precedents_names': ['D50', 'Net Change in Cash:'],
#   'dependent_names': []},
#  {'cell_location': 'E124',
#   'column': 'E',
#   'row': 124,
#   'value': -43,
#   'formula': None,
#   'precedents': ['E50', 'E126'],
#   'dependencies': None,
#   'column_name': '2021-12-31',
#   'row_name': 'FX Rate Effects:',
#   'precedents_names': ['E50', 'Net Change in Cash:'],
#   'dependent_names': []},
#  {'cell_location': 'F124',
#   'column': 'F',
#   'row': 124,
#   'value': 0.4717768322516428,
#   'formula': '=F56*F50',
#   'precedents': ['F38', 'F94', 'F126'],
#   'dependencies': ['F56', 'F50'],
#   'column_name': '2022-12-31',
#   'row_name': 'FX Rate Effects:',
#   'formula_with_row_names': '=Total Revenue:*F50',
#   'precedents_names': ['F38',
#    "Common Shareholders' Equity:",
#    'Net Change in Cash:'],
#   'dependent_names': ['Total Revenue:', 'F50']},
#  {'cell_location': 'G124',
#   'column': 'G',
#   'row': 124,
#   'value': 0.5020182129943402,
#   'formula': '=G56*G50',
#   'precedents': ['G38', 'G94', 'G126'],
#   'dependencies': ['G56', 'G50'],
#   'column_name': '2023-12-31',
#   'row_name': 'FX Rate Effects:',
#   'formula_with_row_names': '=Total Revenue:*G50',
#   'precedents_names': ['G38',
#    "Common Shareholders' Equity:",
#    'Net Change in Cash:'],
#   'dependent_names': ['Total Revenue:', 'G50']},
#  {'cell_location': 'H124',
#   'column': 'H',
#   'row': 124,
#   'value': 0.531920284122122,
#   'formula': '=H56*H50',
#   'precedents': ['H38', 'H94', 'H126'],
#   'dependencies': ['H56', 'H50'],
#   'column_name': '2024-12-31',
#   'row_name': 'FX Rate Effects:',
#   'formula_with_row_names': '=Total Revenue:*H50',
#   'precedents_names': ['H38',
#    "Common Shareholders' Equity:",
#    'Net Change in Cash:'],
#   'dependent_names': ['Total Revenue:', 'H50']},
#  {'cell_location': 'I124',
#   'column': 'I',
#   'row': 124,
#   'value': 0.5607438594977763,
#   'formula': '=I56*I50',
#   'precedents': ['I38', 'I94', 'I126'],
#   'dependencies': ['I56', 'I50'],
#   'column_name': '2025-12-31',
#   'row_name': 'FX Rate Effects:',
#   'formula_with_row_names': '=Total Revenue:*I50',
#   'precedents_names': ['I38',
#    "Common Shareholders' Equity:",
#    'Net Change in Cash:'],
#   'dependent_names': ['Total Revenue:', 'I50']},
#  {'cell_location': 'J124',
#   'column': 'J',
#   'row': 124,
#   'value': 0.5873274275509285,
#   'formula': '=J56*J50',
#   'precedents': ['J38', 'J94', 'J126'],
#   'dependencies': ['J56', 'J50'],
#   'column_name': '2026-12-31',
#   'row_name': 'FX Rate Effects:',
#   'formula_with_row_names': '=Total Revenue:*J50',
#   'precedents_names': ['J38',
#    "Common Shareholders' Equity:",
#    'Net Change in Cash:'],
#   'dependent_names': ['Total Revenue:', 'J50']},
#  {'cell_location': 'B126',
#   'column': 'B',
#   'row': 126,
#   'value': 'Net Change in Cash:',
#   'formula': None,
#   'precedents': None,
#   'dependencies': None,
#   'column_name': None,
#   'row_name': 'Net Change in Cash:',
#   'precedents_names': [],
#   'dependent_names': []},
#  {'cell_location': 'C126',
#   'column': 'C',
#   'row': 126,
#   'value': 113,
#   'formula': '=C109+C114+C122+C124',
#   'precedents': None,
#   'dependencies': ['C109', 'C114', 'C122', 'C124'],
#   'column_name': '2019-12-31',
#   'row_name': 'Net Change in Cash:',
#   'formula_with_row_names': '=Cash Flow from Operations:+Cash Flow from Investing:+Cash Flow from Financing:+FX Rate Effects:',
#   'precedents_names': [],
#   'dependent_names': ['Cash Flow from Operations:',
#    'Cash Flow from Investing:',
#    'Cash Flow from Financing:',
#    'FX Rate Effects:']},
#  {'cell_location': 'D126',
#   'column': 'D',
#   'row': 126,
#   'value': 342,
#   'formula': '=D109+D114+D122+D124',
#   'precedents': None,
#   'dependencies': ['D109', 'D114', 'D122', 'D124'],
#   'column_name': '2020-12-31',
#   'row_name': 'Net Change in Cash:',
#   'formula_with_row_names': '=Cash Flow from Operations:+Cash Flow from Investing:+Cash Flow from Financing:+FX Rate Effects:',
#   'precedents_names': [],
#   'dependent_names': ['Cash Flow from Operations:',
#    'Cash Flow from Investing:',
#    'Cash Flow from Financing:',
#    'FX Rate Effects:']},
#  {'cell_location': 'E126',
#   'column': 'E',
#   'row': 126,
#   'value': 1676,
#   'formula': '=E109+E114+E122+E124',
#   'precedents': None,
#   'dependencies': ['E109', 'E114', 'E122', 'E124'],
#   'column_name': '2021-12-31',
#   'row_name': 'Net Change in Cash:',
#   'formula_with_row_names': '=Cash Flow from Operations:+Cash Flow from Investing:+Cash Flow from Financing:+FX Rate Effects:',
#   'precedents_names': [],
#   'dependent_names': ['Cash Flow from Operations:',
#    'Cash Flow from Investing:',
#    'Cash Flow from Financing:',
#    'FX Rate Effects:']},
#  {'cell_location': 'F126',
#   'column': 'F',
#   'row': 126,
#   'value': -475.0000000000002,
#   'formula': '=F109+F114+F122+F124',
#   'precedents': ['F77'],
#   'dependencies': ['F109', 'F114', 'F122', 'F124'],
#   'column_name': '2022-12-31',
#   'row_name': 'Net Change in Cash:',
#   'formula_with_row_names': '=Cash Flow from Operations:+Cash Flow from Investing:+Cash Flow from Financing:+FX Rate Effects:',
#   'precedents_names': ['Cash:'],
#   'dependent_names': ['Cash Flow from Operations:',
#    'Cash Flow from Investing:',
#    'Cash Flow from Financing:',
#    'FX Rate Effects:']},
#  {'cell_location': 'G126',
#   'column': 'G',
#   'row': 126,
#   'value': -1.312283615106935e-13,
#   'formula': '=G109+G114+G122+G124',
#   'precedents': ['G77'],
#   'dependencies': ['G109', 'G114', 'G122', 'G124'],
#   'column_name': '2023-12-31',
#   'row_name': 'Net Change in Cash:',
#   'formula_with_row_names': '=Cash Flow from Operations:+Cash Flow from Investing:+Cash Flow from Financing:+FX Rate Effects:',
#   'precedents_names': ['Cash:'],
#   'dependent_names': ['Cash Flow from Operations:',
#    'Cash Flow from Investing:',
#    'Cash Flow from Financing:',
#    'FX Rate Effects:']},
#  {'cell_location': 'H126',
#   'column': 'H',
#   'row': 126,
#   'value': 1.6986412276764895e-13,
#   'formula': '=H109+H114+H122+H124',
#   'precedents': ['H77'],
#   'dependencies': ['H109', 'H114', 'H122', 'H124'],
#   'column_name': '2024-12-31',
#   'row_name': 'Net Change in Cash:',
#   'formula_with_row_names': '=Cash Flow from Operations:+Cash Flow from Investing:+Cash Flow from Financing:+FX Rate Effects:',
#   'precedents_names': ['Cash:'],
#   'dependent_names': ['Cash Flow from Operations:',
#    'Cash Flow from Investing:',
#    'Cash Flow from Financing:',
#    'FX Rate Effects:']},
#  {'cell_location': 'I126',
#   'column': 'I',
#   'row': 126,
#   'value': -1.0944578576754793e-12,
#   'formula': '=I109+I114+I122+I124',
#   'precedents': ['I77'],
#   'dependencies': ['I109', 'I114', 'I122', 'I124'],
#   'column_name': '2025-12-31',
#   'row_name': 'Net Change in Cash:',
#   'formula_with_row_names': '=Cash Flow from Operations:+Cash Flow from Investing:+Cash Flow from Financing:+FX Rate Effects:',
#   'precedents_names': ['Cash:'],
#   'dependent_names': ['Cash Flow from Operations:',
#    'Cash Flow from Investing:',
#    'Cash Flow from Financing:',
#    'FX Rate Effects:']},
#  {'cell_location': 'J126',
#   'column': 'J',
#   'row': 126,
#   'value': 1.8299806114896455e-12,
#   'formula': '=J109+J114+J122+J124',
#   'precedents': ['J77'],
#   'dependencies': ['J109', 'J114', 'J122', 'J124'],
#   'column_name': '2026-12-31',
#   'row_name': 'Net Change in Cash:',
#   'formula_with_row_names': '=Cash Flow from Operations:+Cash Flow from Investing:+Cash Flow from Financing:+FX Rate Effects:',
#   'precedents_names': ['Cash:'],
#   'dependent_names': ['Cash Flow from Operations:',
#    'Cash Flow from Investing:',
#    'Cash Flow from Financing:',
#    'FX Rate Effects:']}]

# %%
from fin_statement_model.financial_statement import FinancialStatementGraph

def create_financial_statement(cells_info):
    """
    Create a FinancialStatementGraph object from a list of cell dictionaries.
    Each cell dict is expected to have keys such as 'row_name', 'column_name', and 'value'.

    This function groups cells by the 'row_name' (representing the financial statement item) and
    constructs a mapping of periods (from 'column_name') to values.
    
    Args:
        cells_info (list): List of dictionaries representing Excel cells.
            Example entry:
            {
                'cell_location': 'H63',
                'column': 'H',
                'row': 63,
                'value': 22,
                'formula': '=G63',
                'precedents': ['I63', 'H66'],
                'dependencies': ['G63'],
                'column_name': '2024',
                'row_name': 'Other Income / (Expense):',
                'formula_with_row_names': '=Other Income / (Expense):',
                'precedents_names': ['Other Income / (Expense):', 'Pre-Tax Income:'],
                'dependent_names': ['Other Income / (Expense):']
            },
            ...

    Returns:
        FinancialStatementGraph: The populated financial statement graph.
    """
    # Group cells by row_name to aggregate values per financial statement item
    def clean_text(text: str, chars_to_remove=None) -> str:
        # Ensure the text is not None to avoid AttributeError
        if text is None:
            return ""
        if chars_to_remove is None:
            chars_to_remove = [":"]
        for ch in chars_to_remove:
            text = text.replace(ch, "")
        return text.strip()
    
    from datetime import datetime, date
    # First, group cells by the cleaned row_name while tracking the minimum row index and cell values.
    grouped_items = {}
    for cell in cells_info:
        # Clean the item name using the generic clean_text method to remove standard characters like ':'
        item_name = clean_text(cell.get('row_name'))
        period = cell.get('column_name', '')
        value = cell.get('value')
        row_num = cell.get('row', float('inf'))
    
        if not item_name or not period:
            continue
    
        if item_name not in grouped_items:
            grouped_items[item_name] = {"min_row": row_num, "values": {}}
        else:
            grouped_items[item_name]["min_row"] = min(grouped_items[item_name]["min_row"], row_num)
        grouped_items[item_name]["values"][period] = value

    # Build the final items dictionary,
    # skipping rows that are entirely dates if they are not the first date-only row.
    items = {}
    unique_periods = set()
    for name, data in grouped_items.items():
        if all(isinstance(v, (datetime, date)) for v in data["values"].values()):
            continue
        items[name] = data["values"]
        unique_periods.update(data["values"].keys())

    # Sort periods (assuming they are sortable, e.g., year strings) to pass to FinancialStatementGraph
    sorted_periods = sorted(unique_periods)

    # Create the FinancialStatementGraph with the detected periods
    fsg = FinancialStatementGraph(periods=sorted_periods)

    # Add each financial statement item with its period-value mapping
    for item, values in items.items():
        fsg.add_financial_statement_item(item, values)

    return fsg

# %%
f = create_financial_statement(cells_info)

# %%
f.to_dataframe()
# Out:
#                                   2019-12-31  2020-12-31  2021-12-31  \
# Products                              5648.0      5371.0      6428.0
# Services                              7470.0      7385.0      7870.0
# Total Revenue                        13118.0     12756.0     14298.0
# Cost of Products                     -4640.0     -4439.0     -5293.0
# Cost of Services                     -4652.0     -4538.0     -4812.0
# Operating Expenses                   -1973.0     -2076.0     -2107.0
# Operating Income                      1853.0      1703.0      2086.0
# Other Income / (Expense)               -39.0       -64.0        22.0
# Non-Service Pension Expense             33.0        -6.0       -11.0
# Interest Income / (Expense)             14.0      -122.0      -136.0
# Pre‐Tax Income                        1861.0      1511.0      1961.0
# Income Taxes                          -594.0      -455.0      -541.0
# Net Income                            1267.0      1056.0      1420.0
# (-) NCI Net Income                    -151.0      -150.0      -174.0
# Net Income to Parent                  1116.0       906.0      1246.0
# Cash                                     0.0      1799.0      3475.0
# Accounts Receivable                      0.0      3148.0      3232.0
# Inventory & Other                        0.0      1546.0      1554.0
# Net PP&E, Goodwill & Intangibles         0.0      3031.0      2860.0
# Op. Lease Assets                         0.0       542.0       526.0
# Other Assets                             0.0       644.0       632.0
# Total Assets                             0.0     10710.0     12279.0
# Accounts Payable                         0.0      1453.0      1556.0
# Accrued Liabilities                      0.0      1977.0      1993.0
# Contract Liabilities                     0.0      2542.0      2674.0
# Total Debt                               0.0      5963.0      7273.0
# Op. Lease Liabilities                    0.0       367.0       336.0
# Other Liabilities                        0.0      1609.0      1431.0
# Total Liabilities                        0.0     13911.0     15263.0
# Common Shareholders' Equity              0.0     -3862.0     -3625.0
# Noncontrolling Interests                 0.0       661.0       641.0
# Total Equity                             0.0     -3201.0     -2984.0
# TOTAL LIABILITIES + EQUITY               0.0     10710.0     12279.0
# Balance Check                            0.0         0.0         0.0
# (+/-) Reversal of NCI Net Income       151.0       150.0       174.0
# (+) D&A                                180.0       191.0       203.0
# (+/-) Pensions/Other Items              54.0       156.0       -33.0
# (+/-) Change in WC & Leases            -32.0        77.0       160.0
# Cash Flow from Operations             1469.0      1480.0      1750.0
# (-) CapEx                             -145.0      -183.0      -156.0
# (-) Acquisitions & Other               -58.0      -170.0        67.0
# Cash Flow from Investing              -203.0      -353.0       -89.0
# (+/-) Change in Debt                     6.0      5947.0      1375.0
# (-) Dividends to NCI                  -163.0      -149.0      -155.0
# (-) Stock Repurchases                    0.0         0.0      -725.0
# (+/-) Other Items                     -976.0     -6382.0       -44.0
# Cash Flow from Financing             -1133.0      -844.0        58.0
# FX Rate Effects                        -20.0        59.0       -43.0
# Net Change in Cash                     113.0       342.0      1676.0
#
#                                     2022-12-31    2023-12-31    2024-12-31  \
# Products                           6749.400000  7.165613e+03  7.534130e+03
# Services                           8430.344000  8.987168e+03  9.580771e+03
# Total Revenue                     15179.744000  1.615278e+04  1.711490e+04
# Cost of Products                  -5560.232238 -5.903113e+03 -6.206702e+03
# Cost of Services                  -5195.009409 -5.538140e+03 -5.903934e+03
# Operating Expenses                -2330.162733 -2.479529e+03 -2.627219e+03
# Operating Income                   2094.339620  2.232000e+03  2.377047e+03
# Other Income / (Expense)             22.000000  2.200000e+01  2.200000e+01
# Non-Service Pension Expense         -11.000000 -1.100000e+01 -1.100000e+01
# Interest Income / (Expense)        -181.825000 -2.107442e+02 -2.061446e+02
# Pre‐Tax Income                     1923.514620  2.032255e+03  2.181902e+03
# Income Taxes                       -574.610221 -6.070943e+02 -6.517981e+02
# Net Income                         1348.904399  1.425161e+03  1.530104e+03
# (-) NCI Net Income                 -172.551774 -1.823065e+02 -1.957308e+02
# Net Income to Parent               1176.352625  1.242855e+03  1.334373e+03
# Cash                               3000.000000  3.000000e+03  3.000000e+03
# Accounts Receivable                3588.730009  3.818771e+03  4.046232e+03
# Inventory & Other                  1753.121301  1.864942e+03  1.974053e+03
# Net PP&E, Goodwill & Intangibles   2826.693524  2.791252e+03  2.753700e+03
# Op. Lease Assets                    595.033899  6.331762e+02  6.708905e+02
# Other Assets                        635.968892  6.353846e+02  6.302983e+02
# Total Assets                      12399.547625  1.274353e+04  1.307517e+04
# Accounts Payable                   1698.474528  1.806810e+03  1.912519e+03
# Accrued Liabilities                2238.033333  2.380910e+03  2.520656e+03
# Contract Liabilities               2937.331510  3.124852e+03  3.308263e+03
# Total Debt                         7024.806642  6.871485e+03  6.714614e+03
# Op. Lease Liabilities               405.033899  4.431762e+02  4.808905e+02
# Other Liabilities                  1719.102598  1.828851e+03  1.936194e+03
# Total Liabilities                 16022.782510  1.645608e+04  1.687314e+04
# Common Shareholders' Equity       -4266.328046 -4.357863e+03 -4.445644e+03
# Noncontrolling Interests            643.093161  6.453047e+02  6.476790e+02
# Total Equity                      -3623.234885 -3.712558e+03 -3.797965e+03
# TOTAL LIABILITIES + EQUITY        12399.547625  1.274353e+04  1.307517e+04
# Balance Check                         0.000000  0.000000e+00  0.000000e+00
# (+/-) Reversal of NCI Net Income    172.551774  1.823065e+02  1.957308e+02
# (+) D&A                             217.033603  2.309457e+02  2.447017e+02
# (+/-) Pensions/Other Items           71.031108  7.558428e+01  8.008636e+01
# (+/-) Change in WC & Leases         383.090659  2.066185e+02  1.996398e+02
# Cash Flow from Operations          2020.059768  1.938310e+03  2.054532e+03
# (-) CapEx                          -183.727127 -1.955042e+02 -2.071492e+02
# (-) Acquisitions & Other            -75.000000 -7.500000e+01 -7.500000e+01
# Cash Flow from Investing           -258.727127 -2.705042e+02 -2.821492e+02
# (+/-) Change in Debt               -248.193358 -1.533213e+02 -1.568713e+02
# (-) Dividends to NCI               -170.458613 -1.800950e+02 -1.933565e+02
# (-) Stock Repurchases             -1406.429029 -8.688206e+02 -8.889375e+02
# (+/-) Other Items                     0.000000  0.000000e+00  0.000000e+00
# Cash Flow from Financing          -2236.804418 -1.668307e+03 -1.772915e+03
# FX Rate Effects                       0.471777  5.020182e-01  5.319203e-01
# Net Change in Cash                 -475.000000 -1.312284e-13  1.698641e-13
#
#                                     2025-12-31    2026-12-31
# Products                          7.878080e+03  8.114422e+03
# Services                          1.016424e+04  1.078324e+04
# Total Revenue                     1.804232e+04  1.889766e+04
# Cost of Products                 -6.490051e+03 -6.684753e+03
# Cost of Services                 -6.263483e+03 -6.644930e+03
# Operating Expenses               -2.769582e+03 -2.900881e+03
# Operating Income                  2.519203e+03  2.667100e+03
# Other Income / (Expense)          2.200000e+01  2.200000e+01
# Non-Service Pension Expense      -1.100000e+01 -1.100000e+01
# Interest Income / (Expense)      -2.350115e+02 -2.293127e+02
# Pre‐Tax Income                    2.295191e+03  2.448788e+03
# Income Taxes                     -6.856410e+02 -7.315247e+02
# Net Income                        1.609550e+03  1.717263e+03
# (-) NCI Net Income               -2.058936e+02 -2.196722e+02
# Net Income to Parent              1.403657e+03  1.497591e+03
# Cash                              3.000000e+03  3.000000e+03
# Accounts Receivable               4.265488e+03  4.467705e+03
# Inventory & Other                 2.078846e+03  2.172759e+03
# Net PP&E, Goodwill & Intangibles  2.714112e+03  2.672648e+03
# Op. Lease Assets                  7.072446e+02  7.407734e+02
# Other Assets                      6.208722e+02  6.074437e+02
# Total Assets                      1.338656e+04  1.366133e+04
# Accounts Payable                  2.014046e+03  2.105032e+03
# Accrued Liabilities               2.654962e+03  2.775959e+03
# Contract Liabilities              3.484534e+03  3.643338e+03
# Total Debt                        6.551791e+03  6.383147e+03
# Op. Lease Liabilities             5.172446e+02  5.507734e+02
# Other Liabilities                 2.039358e+03  2.132300e+03
# Total Liabilities                 1.726194e+04  1.759055e+04
# Common Shareholders' Equity      -4.525551e+03 -4.582061e+03
# Noncontrolling Interests          6.501766e+02  6.528414e+02
# Total Equity                     -3.875374e+03 -3.929219e+03
# TOTAL LIABILITIES + EQUITY        1.338656e+04  1.366133e+04
# Balance Check                     0.000000e+00  0.000000e+00
# (+/-) Reversal of NCI Net Income  2.058936e+02  2.196722e+02
# (+) D&A                           2.579615e+02  2.701909e+02
# (+/-) Pensions/Other Items        8.442606e+01  8.842850e+01
# (+/-) Change in WC & Leases       1.912179e+02  1.675971e+02
# Cash Flow from Operations         2.143156e+03  2.243479e+03
# (-) CapEx                        -2.183741e+02 -2.287267e+02
# (-) Acquisitions & Other         -7.500000e+01 -7.500000e+01
# Cash Flow from Investing         -2.933741e+02 -3.037267e+02
# (+/-) Change in Debt             -1.628226e+02 -1.686444e+02
# (-) Dividends to NCI             -2.033960e+02 -2.170074e+02
# (-) Stock Repurchases            -9.226612e+02 -9.556518e+02
# (+/-) Other Items                 0.000000e+00  0.000000e+00
# Cash Flow from Financing         -1.850342e+03 -1.940340e+03
# FX Rate Effects                   5.607439e-01  5.873274e-01
# Net Change in Cash               -1.094458e-12  1.829981e-12

# %%
print(f)
# Out:
# Financial Statement Graph Summary
# ========================================
#
# Periods: 2019-12-31, 2020-12-31, 2021-12-31, 2022-12-31, 2023-12-31, 2024-12-31, 2025-12-31, 2026-12-31
#
# Financial Statement Items:
# -------------------------
# • Products
# • Services
# • Total Revenue
# • Cost of Products
# • Cost of Services
# • Operating Expenses
# • Operating Income
# • Other Income / (Expense)
# • Non-Service Pension Expense
# • Interest Income / (Expense)
# • Pre‐Tax Income
# • Income Taxes
# • Net Income
# • (-) NCI Net Income
# • Net Income to Parent
# • Cash
# • Accounts Receivable
# • Inventory & Other
# • Net PP&E, Goodwill & Intangibles
# • Op. Lease Assets
# • Other Assets
# • Total Assets
# • Accounts Payable
# • Accrued Liabilities
# • Contract Liabilities
# • Total Debt
# • Op. Lease Liabilities
# • Other Liabilities
# • Total Liabilities
# • Common Shareholders' Equity
# • Noncontrolling Interests
# • Total Equity
# • TOTAL LIABILITIES + EQUITY
# • Balance Check
# • (+/-) Reversal of NCI Net Income
# • (+) D&A
# • (+/-) Pensions/Other Items
# • (+/-) Change in WC & Leases
# • Cash Flow from Operations
# • (-) CapEx
# • (-) Acquisitions & Other
# • Cash Flow from Investing
# • (+/-) Change in Debt
# • (-) Dividends to NCI
# • (-) Stock Repurchases
# • (+/-) Other Items
# • Cash Flow from Financing
# • FX Rate Effects
# • Net Change in Cash
#
# Calculations:
# -------------------------
#
# Metrics:
# -------------------------
#
# Forecasted Items:
# -------------------------
